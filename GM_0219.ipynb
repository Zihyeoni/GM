# %% [markdown]
# #Day13. 데이터수집 및 전처리
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**1. 히스토그램 (Histogram)**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
# - 특정 캠페인의 광고 클릭 수 분포를 분석하여 최적의 광고 배포 전략 수립
# - 고객별 구매 금액의 빈도 분포를 분석하여 VIP 고객 타겟팅 수행

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**2. 선형 그래프 (Line Chart)**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
#
# - 특정 마케팅 캠페인의 **주간/월간 매출 트렌드**를 분석하여 성과 평가.
# - **A/B 테스트** 결과를 시간별로 비교하여 전환율이 더 높은 디자인 결정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**3. 막대 그래프 (Bar Chart)**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
#
# - **광고 채널별 전환율 비교** (Google, Facebook, Instagram 등)
# - 제품군별 매출 분석을 통해 **ROI(Return on Investment)가 높은 제품** 파악

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**4. 산점도 (Scatter Plot)**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
#
# - 광고 비용이 **전환율 상승과 직접적인 관계**가 있는지 분석하여 최적의 광고 예산 책정
# - 고객 세그먼트(VIP, Regular)에 따른 광고 클릭 수와 전환율 간 차이를 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**5. 파이 차트 (Pie Chart)**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
#
# - 신규 고객의 유입 경로(SEO, SNS, 유튜브 광고 등) 비율 분석하여 **가장 효과적인 채널** 파악
# - 고객의 **구독 모델 vs 1회성 구매 비율**을 분석하여 지속적인 매출 성장 전략 수립

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**6. 박스 플롯 (Box Plot)**

# %% [markdown]
# 데이터의 **중앙값, 사분위수(Q1, Q3), 이상치(Outlier)** 를 시각적으로 표현하는 그래프
# (이상치: **사분위 범위(IQR, Interquartile Range)를 벗어난 값**)

# %% [markdown]
# **이상치(Outlier)의 정의**
#
# 이상치는 다음 범위를 벗어나는 데이터 포인트 의미
#
# IQR=Q3−Q1\text{IQR} = Q3 - Q1
#
# - 하한 경계값 (Lower Bound):
#
#     Q1−1.5×IQRQ1 - 1.5 \times \text{IQR}
#
# - 상한 경계값 (Upper Bound):
#
#     Q3+1.5×IQRQ3 + 1.5 \times \text{IQR}
#
# - 이상치: **이 범위를 벗어난 값**
#
# ####**박스 플롯에서 이상치 표시 방식**
#
# - 박스(Box): **Q1(25%) ~ Q3(75%) 사이의 값**을 표시 (데이터의 50% 포함)
# - 중앙값(Median, Q2): **박스 내부의 가로선**으로 표시
# - 수염(Whiskers): 이상치를 제외한 데이터의 **최대/최소값**을 연결하는 선
# - **이상치(Outlier): 박스 플롯 바깥쪽의 점(●, x)으로 표시**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
#
# - 광고 캠페인별 **CPC(클릭당 비용) 또는 CPA(전환당 비용) 변동성**을 분석하여 비효율적인 광고 조정
# - 고객별 **평균 구매 금액의 이상치를 분석**하여 VIP 고객과 일반 고객 분류

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이상치는 **IQR 범위를 벗어난 값**으로, 일반적인 데이터 분포에서 벗어난 극단적인 값들을 의미
# 이러한 이상치는 **데이터 정제 과정에서 제거하거나, 별도의 분석 대상으로 고려 가능**

# %% [markdown]
# ##**7. 히트맵 (Heatmap)**

# %% [markdown]
# **그로스 마케팅 활용 예시:**
#
# - 특정 시간대별 **광고 성과 분석**을 통해 ROI가 높은 시간대에 광고 예산을 집중 투자
# - 고객 세그먼트별 **이탈률(Churn Rate) 분석**을 통해 유지율(Retention) 개선

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **📌 그로스 마케팅 그래프 선택 문제**
#
# ### **문제 1: 광고 채널별 전환율 비교**
#
# 한 스타트업이 Google, Facebook, Instagram 3개의 광고 채널에서 광고를 진행했습니다. 각 채널에서 발생한 **전환율(Conversion Rate)** 을 비교하고, 가장 효율적인 광고 채널을 선택하려고 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 선형 그래프 (Line Chart)**
#
# **② 히스토그램 (Histogram)**
#
# **③ 막대 그래프 (Bar Chart)** ✅
#
# **④ 산점도 (Scatter Plot)**
#
# 📝 **정답: ③ 막대 그래프 (Bar Chart)**
#
# - 채널별 전환율을 비교하려면 범주형 데이터 비교가 적합한 **막대 그래프**를 사용해야 함
#
#
#
# ### **문제 2: 고객 세그먼트별 평균 구매 금액 분석**
#
# E-commerce 회사에서 VIP 고객과 일반 고객(Regular)의 **평균 구매 금액(Revenue)** 을 비교하려 합니다. 또한, 일부 고객이 매우 높은 금액을 소비하는지 확인하고 싶습니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 박스 플롯 (Box Plot)** ✅
#
# **② 히트맵 (Heatmap)**
#
# **③ 선형 그래프 (Line Chart)**
#
# **④ 파이 차트 (Pie Chart)**
#
# 📝 **정답: ① 박스 플롯 (Box Plot)**
#
# - 평균뿐만 아니라 **데이터 분포와 이상치(Outlier)** 를 확인하기 위해 **박스 플롯**이 적합
#
# ### **문제 3: 특정 기간 동안의 매출 변화 분석**
#
# 한 온라인 쇼핑몰에서 지난 6개월간의 **월별 매출 변화(Revenue Trend)** 를 분석하여 매출이 증가하는 시기와 감소하는 시기를 파악하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 산점도 (Scatter Plot)**
#
# **② 선형 그래프 (Line Chart)** ✅
#
# **③ 파이 차트 (Pie Chart)**
#
# **④ 히스토그램 (Histogram)**
#
# 📝 **정답: ② 선형 그래프 (Line Chart)**
#
# - 시간에 따른 변화를 분석할 때는 **선형 그래프**가 가장 적절
#
#
#
# ### **문제 4: 웹사이트 방문자의 행동 패턴 분석**
#
# 한 쇼핑몰의 랜딩 페이지에서 방문자들이 **어느 버튼을 가장 많이 클릭하는지** 분석하여 UI 개선을 하려고 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 히트맵 (Heatmap)** ✅
#
# **② 박스 플롯 (Box Plot)**
#
# **③ 막대 그래프 (Bar Chart)**
#
# **④ 선형 그래프 (Line Chart)**
#
# 📝 **정답: ① 히트맵 (Heatmap)**
#
# - 클릭 패턴을 시각적으로 표현하고, 가장 많이 클릭된 영역을 강조하려면 **히트맵**이 적합

# %% [markdown]
# ---
#
# ### **문제 1: 웹사이트 방문자 행동 분석**
#
# 한 이커머스 웹사이트에서 방문자들이 가장 많이 클릭하는 페이지 영역을 분석하고, UI 개선을 위해 활용하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 히스토그램 (Histogram)** ✅
#
# **② 히트맵 (Heatmap)**
#
# **③ 박스 플롯 (Box Plot)**
#
# **④ 산점도 (Scatter Plot)**
#
#
#
# ### **문제 2: 광고 캠페인별 전환율 비교**
#
# 한 기업이 Google, Facebook, Instagram 광고를 진행하고 있습니다. 각 캠페인의 **전환율(Conversion Rate)** 을 비교하여 어떤 채널이 가장 효과적인지 분석하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 선형 그래프 (Line Chart)**
#
# **② 막대 그래프 (Bar Chart)** ✅
#
# **③ 산점도 (Scatter Plot)**
#
# **④ 히트맵 (Heatmap)**
#
#
#
# ### **문제 3: 고객 세그먼트별 평균 구매 금액 분석**
#
# E-commerce 기업에서 VIP 고객과 일반 고객(Regular)의 **평균 구매 금액**을 비교하고, 이상치(극단적인 소비 패턴)를 분석하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 히스토그램 (Histogram)**
#
# **② 박스 플롯 (Box Plot)** ✅
#
# **③ 파이 차트 (Pie Chart)**
#
# **④ 선형 그래프 (Line Chart)**
#
# ### **문제 4: A/B 테스트 결과 분석**
#
# 랜딩 페이지 디자인 A와 B를 비교하고, **각 페이지의 전환율 변화를 1주일 동안 추적**하여 효과적인 디자인을 결정하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 히스토그램 (Histogram)**
#
# **② 산점도 (Scatter Plot)**
#
# **③ 선형 그래프 (Line Chart)** ✅
#
# **④ 박스 플롯 (Box Plot)**
#
#
#
# ### **문제 5: 신규 고객 유입 채널 비율 분석**
#
# 한 마케팅 팀에서 신규 고객이 **SEO, 유튜브 광고, SNS, 이메일 마케팅** 중 어떤 채널을 통해 유입되었는지 비율을 분석하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 파이 차트 (Pie Chart)** ✅
#
# **② 선형 그래프 (Line Chart)**
#
# **③ 박스 플롯 (Box Plot)**
#
# **④ 히스토그램 (Histogram)**
#
#
#
# ### **문제 6: 고객별 광고 클릭 수 분석**
#
# 광고를 클릭한 고객의 수를 분석하여, 특정 광고가 **가장 많은 클릭을 유도했는지** 확인하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 히스토그램 (Histogram)** ✅
#
# **② 박스 플롯 (Box Plot)**
#
# **③ 산점도 (Scatter Plot)**
#
# **④ 선형 그래프 (Line Chart)**
#
# ### **문제 7: 광고 예산과 전환율의 관계 분석**
#
# 광고 예산을 증가시키면 전환율이 함께 증가하는지 확인하기 위해, **광고비와 전환율 간의 관계를 시각화**하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 산점도 (Scatter Plot)** ✅
#
# **② 파이 차트 (Pie Chart)**
#
# **③ 막대 그래프 (Bar Chart)**
#
# **④ 박스 플롯 (Box Plot)**
#
#
#
# ### **문제 8: 고객 유지율(리텐션) 분석**
#
# 한 구독 서비스에서 신규 가입자의 **월별 유지율(Retention Rate)** 을 분석하고, 특정 월에 이탈율이 증가하는지 확인하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 선형 그래프 (Line Chart)** ✅
#
# **② 히스토그램 (Histogram)**
#
# **③ 박스 플롯 (Box Plot)**
#
# **④ 파이 차트 (Pie Chart)**
#
#
#
# ### **문제 9: 특정 시간대별 구매 행동 분석**
#
# 온라인 쇼핑몰에서 고객들이 **가장 많이 구매하는 시간대**를 분석하여, 프로모션 시간을 최적화하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 히트맵 (Heatmap)** ✅
#
# **② 산점도 (Scatter Plot)**
#
# **③ 선형 그래프 (Line Chart)**
#
# **④ 파이 차트 (Pie Chart)**
#
# ### **문제 10: 광고 성과 이상치 감지**
#
# 광고 캠페인에서 **일반적인 클릭당 비용(CPC)보다 너무 높은 비용이 발생한 캠페인을 감지**하려 합니다.
#
# 어떤 그래프를 사용해야 할까요?
#
# **① 박스 플롯 (Box Plot)** ✅
#
# **② 히스토그램 (Histogram)**
#
# **③ 막대 그래프 (Bar Chart)**
#
# **④ 선형 그래프 (Line Chart)**

# %% [markdown]
# ---
#
# #**데이터 변환 (Data Transformation in Growth Marketing)**

# %% [markdown]
# ## **데이터 변환의 중요성**
#
# 그로스 마케팅(Growth Marketing)은 데이터를 기반으로 빠르게 실험하고 최적화하는 과정
#
# 이 과정에서 데이터를 정확하게 분석하려면 데이터 변환(Data Transformation)이 필수적
#
# 데이터 변환을 통해 **데이터 품질을 개선**하고, **비즈니스 인사이트 도출 가능**
#
# ### **데이터 변환이 필요한 이유**
#
# - **데이터 정제(Data Cleaning)**: 결측값, 이상치를 처리하여 신뢰성 있는 데이터 확보
# - **데이터 표준화(Standardization)**: 분석 및 비교를 위해 일관된 데이터 형식 유지
# - **특성 엔지니어링(Feature Engineering)**: 마케팅 인사이트를 도출하기 위한 새로운 변수 생성
# - **머신러닝 모델 준비(Model Preparation)**: 모델 학습을 위한 데이터 전처리 수행

# %% [markdown]
# ### **API 통신 중 발생할 수 있는 결측치와 데이터베이스 저장 형태**
#
# API를 통해 데이터를 주고받을 때, 클라이언트에서 요청한 값이 정상적으로 수신되지 않거나 일부 데이터가 누락되는 경우 발생
# 이러한 결측치는 데이터베이스에 저장될 때 다양한 형태로 나타날 수 있으며, 그 원인과 유형을 이해하는 것 중요

# %% [markdown]
# ---
#
# ###**1. NULL 값으로 저장되는 경우**

# %%
{
  "id": 1,
  "name": "김철수",
  "email": null,
  "phone": "010-1234-5678"
}

# %%
INSERT INTO users (id, name, email, phone) VALUES (1, '김철수', NULL, '010-1234-5678');

# %% [markdown]
# **발생 원인**
#
# - API 제공자가 필드를 명시적으로 `null`로 반환하는 경우
# - 외부 데이터 소스에서 해당 값을 제공하지 않는 경우
# - 클라이언트가 특정 필드를 입력하지 않고 요청을 보낸 경우

# %% [markdown]
# ###**2. 빈 문자열로 저장되는 경우 ("")**

# %%
{
  "id": 2,
  "name": "이영희",
  "email": "",
  "phone": "010-9876-5432"
}

# %%
INSERT INTO users (id, name, email, phone) VALUES (2, '이영희', '', '010-9876-5432');

# %% [markdown]
# **발생 원인**
#
# - API가 `null` 대신 빈 문자열을 반환하는 경우
# - 클라이언트에서 값 입력을 생략했으나 `NULL`이 아닌 빈 값으로 설정한 경우

# %% [markdown]
# ###**3. 0 또는 기본값으로 저장되는 경우**

# %%
{
  "id": 3,
  "name": "박민수",
  "age": 0,
  "salary": 3000000
}

# %%
INSERT INTO employees (id, name, age, salary) VALUES (3, '박민수', 0, 3000000);

# %% [markdown]
# **발생 원인**
#
# - API에서 값이 없을 경우 기본값을 설정하는 경우
# - 데이터 제공자가 특정 필드의 기본값을 `0`으로 정의한 경우
# - 클라이언트가 값을 입력하지 않았으나 API가 자동으로 `0`을 반환한 경우

# %% [markdown]
# ###**4. 데이터 타입이 잘못 저장되는 경우**

# %%
{
  "id": 4,
  "name": "정수빈",
  "age": "unknown",
  "salary": 2500000
}

# %%
INSERT INTO employees (id, name, age, salary) VALUES (4, '정수빈', 'unknown', 2500000);

# %% [markdown]
# **발생 원인**
#
# - API 응답 값이 비정상적인 형식으로 제공된 경우
# - 데이터 타입 검증이 제대로 이루어지지 않은 경우
# - 클라이언트에서 잘못된 데이터를 입력한 경우

# %% [markdown]
# ###**5. 특정 데이터가 아예 저장되지 않는 경우**

# %%
{
  "id": 5,
  "name": "최진혁"
}

# %%
INSERT INTO users (id, name, email, phone) VALUES (5, '최진혁', NULL, NULL);

# %% [markdown]
# **발생 원인**
#
# - API 설계 변경으로 인해 특정 필드가 더 이상 제공되지 않는 경우
# - 외부 데이터 소스에서 해당 정보를 제공하지 않는 경우
# - 요청 시 일부 필드만 선택적으로 제공하는 경우

# %% [markdown]
# ---
#
# API 통신 중 발생하는 결측치는 데이터베이스에 다음과 같은 방식으로 저장됨
#
# 1. `NULL` 값으로 저장됨 (`null` 응답)
# 2. 빈 문자열로 저장됨 (`""` 응답)
# 3. `0` 또는 기본값으로 저장됨
# 4. 잘못된 데이터 형식으로 저장됨 (예: `int` 필드에 `string`)
# 5. 필드 자체가 누락되어 `NULL`로 저장되거나 기본값으로 채워짐
#
# 데이터베이스에서 결측치를 처리할 때는 다음과 같은 방법을 고려
#
# - **`NULL` 값 변환:** `COALESCE()` 함수를 사용하여 `NULL` 값을 기본값으로 변환
# - **데이터 타입 검증:** API 응답 데이터를 저장하기 전에 데이터 타입을 변환 또는 검증
# - **기본값 설정:** `DEFAULT` 값을 설정하여 필드가 `NULL`이 아닐 때 기본값을 자동 삽입

# %% [markdown]
# ---
#
# ##**데이터 변환 기법**

# %% [markdown]
# ### **1) 데이터 정제 (Data Cleaning)**
#
# 그로스 마케팅 데이터를 분석하기 전에 **결측값과 이상치 처리** 필수
#
# - 결측값이 있으면 평균값 또는 중앙값으로 대체
# - 이상치(극단값)는 제거하거나 다른 값으로 조정

# %%
import pandas as pd
import numpy as np

# 예제 데이터 생성
data = {
    "Age": [25, 30, np.nan, 40, 35],  # 결측값 포함
    "Ad Influence": [5, np.nan, 3, 4, 5],  # 결측값 포함
    "Product Satisfaction": [np.nan, 4, 3, 5, 4]  # 결측값 포함
}

df = pd.DataFrame(data)

# 결측값을 평균으로 대체
df.fillna(df.mean(), inplace=True)

print(df)
# Out:
#     Age  Ad Influence  Product Satisfaction
# 0  25.0          5.00                   4.0
# 1  30.0          4.25                   4.0
# 2  32.5          3.00                   3.0
# 3  40.0          4.00                   5.0
# 4  35.0          5.00                   4.0

# %% [markdown]
# **결측치 확인 "isnull() 함수"** : 데이터프레임(DataFrame) 또는 시리즈(Series)에서 결측치(NaN)를 확인하는 함수
# 결과는 각 값이 결측치인지(True) 또는 아닌지(False)를 나타내는 불리언(Boolean) 값으로 반환

# %%
import pandas as pd
import numpy as np

data_example = {
    "User ID": [1, 2, 3, 4, 5],
    "Ad Clicks": [10, np.nan, 25, 30, np.nan],  # 일부 결측치 포함
    "Conversion Rate": [0.05, 0.07, np.nan, 0.12, 0.09],  # 일부 결측치 포함
    "Revenue": [1000, 2000, np.nan, 4000, 5000]  # 일부 결측치 포함
}

# 데이터프레임 생성
df_example = pd.DataFrame(data_example)

# 결측치 확인 코드
missing_values_example = df_example.isnull().sum()

# 데이터 및 결측치 개수 출력
print("Example Dataset:")
print(df_example)
print("\nMissing Values Count:")
print(missing_values_example)
# Out:
# Example Dataset:
#    User ID  Ad Clicks  Conversion Rate  Revenue
# 0        1       10.0             0.05   1000.0
# 1        2        NaN             0.07   2000.0
# 2        3       25.0              NaN      NaN
# 3        4       30.0             0.12   4000.0
# 4        5        NaN             0.09   5000.0
#
# Missing Values Count:
# User ID            0
# Ad Clicks          2
# Conversion Rate    1
# Revenue            1
# dtype: int64

# %% [markdown]
# - 위 내용을 fillna()를 이용해 결측치가 있는 컬럼의 평균값으로 결측치 대체

# %%
df_example.fillna(df_example.mean(), inplace=True)
print(df_example)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Revenue
# 0        1  10.000000           0.0500   1000.0
# 1        2  21.666667           0.0700   2000.0
# 2        3  25.000000           0.0825   3000.0
# 3        4  30.000000           0.1200   4000.0
# 4        5  21.666667           0.0900   5000.0

# %% [markdown]
# - csv파일을 로딩해서 결측치를 확인하고 제거(평균값으로 대체)

# %%
df_example2 = pd.read_csv("growth_marketing_dataset.csv", encoding="utf-8-sig")
null_values = df_example2.isnull().sum()
print(null_values)
# Out:
# User ID              0
# Age                  0
# Ad Clicks           20
# Conversion Rate     20
# Revenue             20
# Campaign             0
# Customer Segment     0
# dtype: int64

# %%
df_example2.fillna(df_example2.mean(numeric_only=True), inplace=True)
print(df_example2)
print(df_example2.isnull().sum())
# Out:
#     User ID  Age  Ad Clicks  Conversion Rate  Revenue   Campaign  \
# 0         1   48    42.0000         0.100000   8824.0     Google
# 1         2   56    23.2125         0.020000   2349.0      Email
# 2         3   56    23.2125         0.079125   5484.0     Google
# 3         4   28     8.0000         0.030000   4706.0  Instagram
# 4         5   54    22.0000         0.130000   2281.0      Email
# ..      ...  ...        ...              ...      ...        ...
# 95       96   62    44.0000         0.030000   3263.0      Email
# 96       97   35    39.0000         0.070000   1779.0     Google
# 97       98   51     4.0000         0.130000   3711.0      Email
# 98       99   52    46.0000         0.020000   5708.0   Facebook
# 99      100   58    40.0000         0.070000   1400.0  Instagram
#
#    Customer Segment
# 0               VIP
# 1               VIP
# 2               VIP
# 3               New
# 4           Regular
# ..              ...
# 95              New
# ...

# %% [markdown]
# ### **2) 데이터 타입 변환 (Data Type Conversion)**
#
# 그로스 마케팅 데이터를 분석할 때는 **데이터 유형을 적절하게 변환**해야 함
#
# - **문자열을 숫자로 변환** (예: "Yes"/"No" → 1/0)
# - **날짜 데이터를 변환하여 분석 가능하도록 변경**

# %%
# 광고 시청 여부를 0과 1로 변환
df["Ad Viewed"] = ["Yes", "No", "Yes", "No", "Yes"]
df["Ad Viewed"] = df["Ad Viewed"].map({"Yes": 1, "No": 0})

# 날짜 데이터 변환
df["Survey Date"] = pd.to_datetime(["2024-02-01", "2024-02-02", "2024-02-03", "2024-02-04", "2024-02-05"])

print(df["Ad Viewed"])
print(df)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Ad Viewed, dtype: int64
#     Age  Ad Influence  Product Satisfaction  Ad Viewed Survey Date
# 0  25.0          5.00                   4.0          1  2024-02-01
# 1  30.0          4.25                   4.0          0  2024-02-02
# 2  32.5          3.00                   3.0          1  2024-02-03
# 3  40.0          4.00                   5.0          0  2024-02-04
# 4  35.0          5.00                   4.0          1  2024-02-05

# %% [markdown]
# ### **3) 범주형 데이터 변환 (Categorical Encoding)**
#
# 광고 캠페인이나 고객 세그먼트 같은 **범주형 데이터**는 머신러닝 모델에서 바로 사용할 수 없기 때문에 숫자로 변환해야 함
#
# - **레이블 인코딩(Label Encoding)**: 범주형 데이터를 숫자로 변환
# - **원-핫 인코딩(One-Hot Encoding)**: 범주형 데이터를 여러 개의 이진(0/1) 컬럼으로 변환

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# 예제 데이터 생성 (결측값 포함)
data = {
    "User ID": [101, 102, 103, 104, 105],
    "Age": [25, 30, np.nan, 40, 35],  # 결측값 포함
    "Ad Clicks": [10, 50, 35, 30, 60],
    "Conversion Rate": [0.02, 0.05, 0.03, 0.04, 0.07],
    "Ad Influence": [5, np.nan, 3, 4, 5],  # 결측값 포함
    "Product Satisfaction": [np.nan, 4, 3, 5, 4],  # 결측값 포함
    "Campaign": ["YouTube Ad", "SNS Ad", "Search Ad", "Email Marketing", "SNS Ad"]
}

df = pd.DataFrame(data)

# 결측값을 각 컬럼의 평균으로 대체
df.fillna(df.mean(numeric_only=True), inplace=True)

# 레이블 인코딩 (Campaign을 숫자로 변환)
le = LabelEncoder()
df["Campaign_Encoded"] = le.fit_transform(df["Campaign"])

# 원-핫 인코딩 적용
df_one_hot = pd.get_dummies(df, columns=["Campaign"])

# 최종 결과 출력
print(df_one_hot)
# Out:
#    User ID   Age  Ad Clicks  Conversion Rate  Ad Influence  \
# 0      101  25.0         10             0.02          5.00
# 1      102  30.0         50             0.05          4.25
# 2      103  32.5         35             0.03          3.00
# 3      104  40.0         30             0.04          4.00
# 4      105  35.0         60             0.07          5.00
#
#    Product Satisfaction  Campaign_Encoded  Campaign_Email Marketing  \
# 0                   4.0                 3                     False
# 1                   4.0                 1                     False
# 2                   3.0                 2                     False
# 3                   5.0                 0                      True
# 4                   4.0                 1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad
# 0            False               False                 True
# 1             True               False                False
# ...

# %% [markdown]
# ### **4) 데이터 스케일링 (Data Scaling)**
#
# 광고 영향도(Ad Influence), 제품 만족도(Product Satisfaction) 등 **연속형 변수**는 범위가 다를 수 있음
#
# 따라서 **모델 학습과 비교를 위해 정규화(Normalization) 또는 표준화(Standardization) 적용**이 필요

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[["Ad Influence", "Product Satisfaction"]] = scaler.fit_transform(df[["Ad Influence", "Product Satisfaction"]])

print(df)
# Out:
#    User ID   Age  Ad Clicks  Conversion Rate  Ad Influence  \
# 0      101  25.0         10             0.02         1.000
# 1      102  30.0         50             0.05         0.625
# 2      103  32.5         35             0.03         0.000
# 3      104  40.0         30             0.04         0.500
# 4      105  35.0         60             0.07         1.000
#
#    Product Satisfaction         Campaign  Campaign_Encoded
# 0                   0.5       YouTube Ad                 3
# 1                   0.5           SNS Ad                 1
# 2                   0.0        Search Ad                 2
# 3                   1.0  Email Marketing                 0
# 4                   0.5           SNS Ad                 1

# %% [markdown]
# ### **5) 피처 엔지니어링 (Feature Engineering)**
#
# 그로스 마케팅에서는 기존 데이터를 가공하여 **새로운 인사이트를 얻을 수 있는 변수를 추가**하는 것이 중요
#
# 예를 들어, **만족도 점수를 기반으로 고객 그룹화**

# %%
# 제품 만족도 점수가 4 이상이면 "High", 그렇지 않으면 "Low"
df["Satisfaction Level"] = df["Product Satisfaction"].apply(lambda x: "High" if x >= 0.8 else "Low")

print(df)
# Out:
#    User ID   Age  Ad Clicks  Conversion Rate  Ad Influence  \
# 0      101  25.0         10             0.02         1.000
# 1      102  30.0         50             0.05         0.625
# 2      103  32.5         35             0.03         0.000
# 3      104  40.0         30             0.04         0.500
# 4      105  35.0         60             0.07         1.000
#
#    Product Satisfaction         Campaign  Campaign_Encoded Satisfaction Level
# 0                   0.5       YouTube Ad                 3                Low
# 1                   0.5           SNS Ad                 1                Low
# 2                   0.0        Search Ad                 2                Low
# 3                   1.0  Email Marketing                 0               High
# 4                   0.5           SNS Ad                 1                Low

# %% [markdown]
# ---
#
# ##**예제) "꽃을 든 남자" 상품에 대한 고객행동분석**

# %% [markdown]
# - Customer ID : 고객 ID
# - Age	: 연령 (18~65세)
# - Gender : 성별
# - Product Category : 구매한 상품 카테고리 (Skincare: 스킨케어, Fragrance: 향수, Haircare: 헤어케어, Bodycare: 바디케어)
# - Purchase Amount : 구매 금액 (단위: 원)
# - Purchase Frequency : 구매 빈도 (해당 브랜드에서 구매한 총 횟수)
# - Review Rating : 제품 리뷰 평점 (1~5점, 일부 결측 포함)
# - Return Rate : 반품률 (0~50%, 일부 결측 포함)
# - Marketing Channel : 유입된 마케팅 채널 (Instagram, Facebook, YouTube, Email, Website)
# - Coupon Used	: 쿠폰 사용 여부 (0: 미사용, 1: 사용)

# %%
df_flower = pd.read_csv("고객행동분석_꽃을든남자.csv", encoding="utf-8-sig")
display(df_flower)
display(df_flower.info())
# Out:
#     Customer ID  Age  Gender Product Category  Purchase Amount  \
# 0             1   56  Female         Skincare         72559.21
# 1             2   46  Female         Haircare         81902.60
# 2             3   32    Male        Fragrance         38123.27
# 3             4   60    Male         Skincare         14136.77
# 4             5   25    Male         Skincare         94349.71
# ..          ...  ...     ...              ...              ...
# 95           96   24    Male         Bodycare         17979.03
# 96           97   26  Female         Bodycare         72346.54
# 97           98   41  Female         Haircare         57517.90
# 98           99   18    Male         Bodycare         33168.46
# 99          100   61  Female         Haircare         44879.18
#
#     Purchase Frequency  Review Rating  Return Rate Marketing Channel  \
# 0                 18.0            NaN         0.43           YouTube
# ...

# %%
# 결측값 변경
df_flower.fillna(df_flower.mean(numeric_only=True), inplace=True)
display(df_flower.isnull().sum())

# "Purchase Frequency" Dtype 정수형으로 변경
df_flower = df_flower.astype({"Purchase Frequency" : 'int'})
print(df_flower.info())
# Out:
# Customer ID           0
# Age                   0
# Gender                0
# Product Category      0
# Purchase Amount       0
# Purchase Frequency    0
# Review Rating         0
# Return Rate           0
# Marketing Channel     0
# Coupon Used           0
# age_group             0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         100 non-null    int64
#  1   Age                 100 non-null    int64
#  2   Gender              100 non-null    object
#  3   Product Category    100 non-null    object
#  4   Purchase Amount     100 non-null    float64
#  5   Purchase Frequency  100 non-null    int64
#  6   Review Rating       100 non-null    float64
#  7   Return Rate         100 non-null    float64
#  8   Marketing Channel   100 non-null    object
# ...

# %% [markdown]
# **데이터 분석**

# %%
# 데이터 개요 출력
print("데이터 개요:"), display(df_flower)

# 고객 연령대별 구매 금액 평균 확인
df_flower["age_group"] = pd.cut(df_flower["Age"], bins=[10, 20, 30, 40, 50, 60, 100], labels=["10s", "20s", "30s", "40s", "50s", "60s"])
amounts_per_age = df_flower.groupby("age_group", observed=False)["Purchase Amount"].mean()
print("\n고객 연령대별 구매 평균 금액:"), display(amounts_per_age)

# 고객 연령대별 쿠폰 사용 빈도
coupon_per_age = df_flower.groupby("age_group", observed=False)["Coupon Used"].sum()
print("\n고객 연령대별 쿠폰 사용량:"), display(coupon_per_age)

# 상품 카테고리별 총 판매량
purchase_per_category = df_flower.groupby("Product Category")["Purchase Frequency"].sum()
print("\n상품 카테고리별 판매량:"), display(purchase_per_category)

# 고객 성별 비율
gender_rate = df_flower["Gender"].value_counts(normalize=True) * 100
print("\n고객 성별 비율(%):"), display(gender_rate)

# 성별, 상품 카테고리별 판매량
category_per_gender = df_flower.groupby(["Gender", "Product Category"])["Purchase Frequency"].sum()
print("\n고객 성별에 따른 판매량:"), display(category_per_gender)

# 상품 카테고리별 리뷰 평균 평점
review_per_category = df_flower.groupby("Product Category")["Review Rating"].mean()
print("\n상품 카테고리별 리뷰 평점(1~5):"), display(review_per_category)

# 상품 카테고리별 반품률
return_per_category = df_flower.groupby("Product Category")["Return Rate"].mean() * 100
print("\n상품 카테고리별 반품률(0~50%):"), display(return_per_category)

# 마케팅 채널별 총 판매량
purchase_per_channel = df_flower.groupby("Marketing Channel")["Purchase Frequency"].sum()
print("\n마케팅 채널별 판매량:"), display(purchase_per_channel)

# 구매 빈도 수와 제품 리뷰 평점과의 상관관계
fre_review_corr = df_flower[["Purchase Frequency", "Review Rating"]].corr()
print("\n제품 판매량과 제품 리뷰 평점과의 상관관계:"), display(fre_review_corr)

# 구매 금액과 구매 빈도와의 상관관계
amt_fre_corr = df_flower[["Purchase Amount", "Purchase Frequency"]].corr()
print("\n구매 금액과 판매량의 상관관계:"), display(amt_fre_corr)
# Out:
# 데이터 개요:
#     Customer ID  Age  Gender Product Category  Purchase Amount  \
# 0             1   56  Female         Skincare         72559.21
# 1             2   46  Female         Haircare         81902.60
# 2             3   32    Male        Fragrance         38123.27
# 3             4   60    Male         Skincare         14136.77
# 4             5   25    Male         Skincare         94349.71
# ..          ...  ...     ...              ...              ...
# 95           96   24    Male         Bodycare         17979.03
# 96           97   26  Female         Bodycare         72346.54
# 97           98   41  Female         Haircare         57517.90
# 98           99   18    Male         Bodycare         33168.46
# 99          100   61  Female         Haircare         44879.18
#
#     Purchase Frequency  Review Rating  Return Rate Marketing Channel  \
# 0                   18       3.056818         0.43           YouTube
# ...

# %% [markdown]
# **데이터 시각화**

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 94.8 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 고객 연령대별 구매 금액 평균 확인
plt.figure(figsize=(6, 4))
amounts_per_age.plot(kind='bar')
plt.title("고객 연령대별 구매 금액")
plt.xlabel("고객 연령대")
plt.ylabel("구매 금액 평균(원)")
plt.show()

# 고객 연령대별 쿠폰 사용 빈도
plt.figure(figsize=(6, 4))
coupon_per_age.plot(kind='bar')
plt.title("고객 연령대별 쿠폰 사용량")
plt.xlabel("고객 연령대")
plt.ylabel("쿠폰 사용 횟수")
plt.show()

# 상품 카테고리별 총 판매량
plt.figure(figsize=(6, 4))
purchase_per_category.plot(kind='bar',color=['blue', 'green', 'red', 'purple'] )
plt.title("상품 카테고리별 판매량")
plt.xlabel("상품 카테고리")
plt.ylabel("판매량")
plt.show()

# 고객 성별 비율
gender_rate.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'salmon'])
plt.title("고객 성별 비율")
plt.ylabel("")
plt.show()

# 성별, 상품 카테고리별 판매량
plt.figure(figsize=(6, 4))
category_per_gender.plot(kind='bar',color=['blue', 'green', 'red', 'purple'] )
plt.title("성별 및 상품 카테고리별 판매량")
plt.xlabel("성별 & 상품 카테고리")
plt.ylabel("판매량")
plt.show()

# 상품 카테고리별 리뷰 평균 평점
plt.figure(figsize=(6, 4))
review_per_category.plot(kind='bar',color=['blue', 'green', 'red', 'purple', 'orange'] )
plt.title("상품 카테고리별 리뷰 평점(1~5)")
plt.xlabel("상품 카테고리")
plt.ylabel("리뷰 평점 평균")
plt.show()

# 상품 카테고리별 반품률
plt.figure(figsize=(6, 4))
return_per_category.plot(kind='bar',color=['blue', 'green', 'red', 'purple'] )
plt.title("상품 카테고리별 반품률(0~50%)")
plt.xlabel("상품 카테고리")
plt.ylabel("반품률(%)")
plt.show()

# 마케팅 채널별 총 판매량
plt.figure(figsize=(6, 4))
purchase_per_channel.plot(kind='bar',color=['blue', 'green', 'red', 'purple', 'orange'] )
plt.title("유입 마케팅 채널별 판매량")
plt.xlabel("마케팅 채널")
plt.ylabel("판매량")
plt.show()

# 구매 빈도 수와 제품 리뷰 평점과의 상관관계 히트맵
plt.figure(figsize=(6, 4))
sns.heatmap(fre_review_corr, annot=True, cmap="Blues", linewidths=0.5, fmt=".2f")
plt.title("Correlation: 판매량 vs. 리뷰 평점")
plt.show()


# 구매 금액과 구매 빈도와의 상관관계 히트맵
plt.figure(figsize=(6, 4))
sns.heatmap(amt_fre_corr, annot=True, cmap="Blues", linewidths=0.5, fmt=".2f")
plt.title("Correlation: 구매 금액 vs. 판매량")
plt.show()

# %% [markdown]
# ---
#
# ##**데이터 변환을 활용한 그로스 마케팅 분석 사례**

# %% [markdown]
# ###**1) 광고 캠페인별 효과 분석**
#
# 그로스 마케팅에서 가장 중요한 것은 **광고 캠페인의 효과를 분석**하는 것
# 예를 들어, 캠페인별 **광고 영향도(Ad Influence) 평균을 계산하여 효과적인 캠페인을 식별 가능**

# %%
import pandas as pd
import numpy as np

# 새로운 데이터 생성 (광고 캠페인별 효과 분석)
data = {
    "Campaign": np.random.choice(["Google Ads", "Facebook Ads", "Instagram Ads", "YouTube Ads", "Email Marketing"], 100),  # 캠페인명
    "Ad Influence": np.random.randint(1, 10, 100),  # 광고 영향도 (1~10점)
    "Click Through Rate (CTR)": np.round(np.random.uniform(0.02, 0.18, 100), 3),  # 클릭률 (2%~18%)
    "Conversion Rate": np.round(np.random.uniform(0.02, 0.25, 100), 3),  # 전환율 (2%~25%)
    "Revenue": np.random.randint(2000, 15000, 100),  # 매출 (2,000~15,000원)
    "Customer Segment": np.random.choice(["VIP", "Regular", "New"], 100),  # 고객 세그먼트
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 광고 캠페인별 광고 영향도 평균 계산
campaign_ad_influence = df.groupby("Campaign")["Ad Influence"].mean().reset_index()

# 전체 데이터셋 출력 (상위 10개 행)
print("Ad Campaign Effectiveness Dataset (Top 10 Rows):")
print(df.head(10))

# 캠페인별 광고 영향도 평균 출력
print("\n Campaign Ad Influence Summary:")
print(campaign_ad_influence)
# Out:
# Ad Campaign Effectiveness Dataset (Top 10 Rows):
#           Campaign  Ad Influence  Click Through Rate (CTR)  Conversion Rate  \
# 0  Email Marketing             6                     0.148            0.141
# 1       Google Ads             1                     0.154            0.048
# 2     Facebook Ads             4                     0.105            0.144
# 3     Facebook Ads             8                     0.070            0.230
# 4     Facebook Ads             3                     0.088            0.244
# 5    Instagram Ads             8                     0.122            0.077
# 6     Facebook Ads             7                     0.161            0.169
# 7      YouTube Ads             2                     0.039            0.245
# 8      YouTube Ads             6                     0.065            0.214
# 9       Google Ads             5                     0.069            0.226
#
#    Revenue Customer Segment
# 0    11430              New
# ...

# %% [markdown]
# **광고 캠페인별 주요 성과 분석**
#
# **Ad Influence(광고 영향도) 평균 비교**
#
# | **Campaign** | **Ad Influence (평균)** |
# | --- | --- |
# | **YouTube Ads** | **4.35** |
# | **Email Marketing** | **4.19** |
# | **Google Ads** | **4.64** |
# | **Facebook Ads** | **5.74** |
# | **Instagram Ads** | **5.75** |
#
# **분석**
#
# - **Instagram(5.75)** 과 **Facebook Ads(5.74)** 광고 영향도가 가장 높음
# - **Email Marketing(4.19)**가 가장 낮은 광고 영향도를 보임
# - YouTube Ads와 Google Ads는 중간 수준의 영향도를 가짐

# %% [markdown]
# **개별 광고 데이터 분석 (Top 10)**
#
# - `Ad Influence`: **1 ~ 8**까지 다양한 분포
# - `Click Through Rate (CTR)`: **0.039 ~ 0.161** (클릭률이 3.9%~16.1%로 차이 큼)
# - `Conversion Rate`: **0.048 ~ 0.245** (전환율도 4.8%~24.5%로 차이 큼)
# - `Revenue`: **2,360원 ~ 12,938원** (매출이 캠페인마다 큰 차이 보임)
# - `Customer Segment`: **VIP, Regular, New** 다양한 고객층이 포함됨
#
# **분석**
#
# - **광고 영향도가 높은 Instagram(5.75)**이 실제 클릭률과 전환율에서도 좋은 성과를 내는지 추가 분석 필요
# - **Email Marketing은 광고 영향도가 낮지만, 개별 광고의 성과 분석이 필요** (일부 광고가 효과적일 수도 있음)
# - **YouTube Ads는 광고 영향도는 낮지만 일부 높은 전환율(24.5%)을 기록함** → 특정 고객층에서 효과적일 가능성 있음

# %% [markdown]
# **마케팅 전략 개선 방향**
#
#  **Instagram Ads & Facebook Ads → 유지 및 확장**
#
# - 광고 영향도가 **가장 높음 (5.75, 5.74)**
# - 추가적으로 클릭률(CTR)과 전환율이 높은 광고를 분석하여 **예산 증액 가능**
#
#  **Email Marketing → 전략 수정 필요**
#
# - 광고 영향도가 가장 낮음 (4.19)
# - **콘텐츠 개선 or 광고 타겟 조정 필요**
# - CTR과 전환율이 높은 특정 고객 세그먼트 분석 후 최적화 진행
#
#  **YouTube Ads → 특정 타겟에 집중**
#
# - 광고 영향도가 낮지만 일부 **전환율이 높은 광고 발견**
# - 특정 고객 세그먼트에서 효과적인지 추가 분석 후 **타겟 마케팅 진행**

# %% [markdown]
# ✔ **Instagram Ads & Facebook Ads → 광고 예산 증액 가능 (성과 우수)**
#
# ✔ **Email Marketing → 광고 콘텐츠 및 타겟 전략 수정 필요**
#
# ✔ **YouTube Ads → 특정 고객군(전환율 높은 고객) 집중 마케팅 진행**

# %% [markdown]
# ###**2) 고객 세그먼트 분석**
#
# 광고 시청 여부와 연령대별 **재구매 의향(Repurchase Intent) 비교**, 어떤 고객 그룹이 재구매율 높은지 확인 가능

# %%
import pandas as pd
import numpy as np

# 예제 데이터 생성
data = {
    "User ID": [101, 102, 103, 104, 105],
    "Age": [25, 30, 35, 40, 45],
    "Repurchase Intent": [1, 0, 1, 1, 0]  # 1: 재구매 의향 있음, 0: 없음
}

df = pd.DataFrame(data)

# 연령대 구분 (예: 20대, 30대, 40대)
bins = [20, 30, 40, 50]  # 연령대 구간 설정
labels = ["20s", "30s", "40s"]
df["Age Group"] = pd.cut(df["Age"], bins=bins, labels=labels, right=False)

# 연령대별 재구매율 분석 (observed=False 추가)
repurchase_rate = df.groupby("Age Group", observed=False)["Repurchase Intent"].mean() * 100

# 결과 출력
print(repurchase_rate)
# Out:
# Age Group
# 20s    100.0
# 30s     50.0
# 40s     50.0
# Name: Repurchase Intent, dtype: float64

# %% [markdown]
# ###**3) 그로스 마케팅에서 활용되는 데이터 변환 예시**

# %% [markdown]
# - **데이터 정제(Data Cleaning)**: 결측값 및 이상치를 제거하여 신뢰성 있는 데이터 확보
# - **데이터 변환(Data Transformation)**: 문자열, 숫자, 날짜 변환
# - **데이터 인코딩(Categorical Encoding)**: 머신러닝 분석을 위한 범주형 데이터 변환
# - **데이터 스케일링(Data Scaling)**: 모델링 및 비교 분석을 위한 값 변환
# - **특성 엔지니어링(Feature Engineering)**: 광고 효과 분석 및 고객 세그먼트화

# %% [markdown]
# 그로스 마케팅에서는 고객 행동 데이터, 광고 성과 데이터, 전환율 분석 데이터 등 다양한 유형의 데이터를 다룸
#
# 효과적인 분석과 모델링을 위해 데이터 변환을 수행해야 하며, 다음과 같은 변환 기법 활용
#
# - **결측값 처리** → 광고 클릭, 전환율 등 데이터 손실 방지
# - **데이터 변환** → 숫자 변환, 인코딩, 로그 변환 등을 활용하여 비교 가능하게 변환
# - **스케일링 적용** → 정규화 및 표준화를 통해 광고 비용, 클릭 수 등의 비교 가능
# - **피처 엔지니어링** → 고객 세그먼트, 날짜 기반 변수 등을 추가하여 분석력 향상
# - **이상치 제거** → 광고 효과 분석의 정확성을 높이기 위해 극단값 조정

# %% [markdown]
# ### **1. 결측값 처리 (Handling Missing Values)**

# %% [markdown]
# 그로스 마케팅 데이터를 분석하는 과정에서 **설문조사 응답 누락, 광고 클릭 수 누락, 고객 정보 불완전성** 등으로 인해 데이터에 결측값(Missing Values) 존재 가능
#
# 결측값이 포함된 데이터를 그대로 사용하면 **광고 성과 분석, 전환율 예측, 고객 세분화 등의 정확성이 낮아질 수 있으므로, 적절한 결측값 처리 기법을 적용해야 함**
#
# **1.1 결측값을 평균(Mean) 또는 중앙값(Median)으로 대체**
#
# **1.1.1 평균(Mean)으로 대체**
#
# 평균: **모든 데이터의 합을 데이터 개수로 나눈 값**
#
# - 예를 들어, 광고 클릭 수(Ad Clicks) 데이터가 `[10, 50, NaN, 30, 60]` 일 때,
#     - 결측값을 평균값 **(10+50+30+60)/4 = 37.5**로 대체 가능
# - **장점:** 이상치(극단값)가 적은 경우 효과적
# - **단점:** 이상치가 존재하면 평균이 왜곡 가능

# %%
import pandas as pd
import numpy as np

# 예제 데이터 생성
data = {
    "User ID": [101, 102, 103, 104, 105],
    "Ad Clicks": [10, 50, np.nan, 30, 60],  # 결측값 포함
    "Conversion Rate": [0.02, 0.05, 0.03, np.nan, 0.07]  # 결측값 포함
}

df = pd.DataFrame(data)

# 평균으로 결측값 대체
df["Ad Clicks"].fillna(df["Ad Clicks"].mean())
df["Conversion Rate"].fillna(df["Conversion Rate"].mean())

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate
# 0      101       10.0             0.02
# 1      102       50.0             0.05
# 2      103        NaN             0.03
# 3      104       30.0              NaN
# 4      105       60.0             0.07

# %% [markdown]
# **1.1.2 중앙값(Median)으로 대체**
#
# 중앙값은 **데이터를 정렬한 후 가운데 위치한 값**이다.
#
# - 예를 들어, 광고 클릭 수 데이터가 `[10, 30, NaN, 50, 60]`일 때,
#     - 정렬 후 `[10, 30, NaN, 50, 60]` → 중앙값은 **30**
#     - 결측값을 **30**으로 대체 가능
# - **장점:** 이상치(극단값)의 영향을 덜 받음
# - **단점:** 데이터가 정규분포를 따를 경우, 평균이 더 나은 선택일 수 있음

# %%
# 중앙값으로 결측값 대체
df["Ad Clicks"].fillna(df["Ad Clicks"].median())
df["Conversion Rate"].fillna(df["Conversion Rate"].median())

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate
# 0      101       10.0             0.02
# 1      102       50.0             0.05
# 2      103        NaN             0.03
# 3      104       30.0              NaN
# 4      105       60.0             0.07

# %% [markdown]
# **1.2 평균과 중앙값 대체 방법 비교**
#
# | 방법 | 장점 | 단점 | 추천 상황 |
# | --- | --- | --- | --- |
# | **평균(Mean) 대체** | 데이터의 전체적인 대표값을 유지 | 이상치(극단값)가 있으면 왜곡될 가능성 있음 | **이상치가 적고 정규분포를 따르는 경우** |
# | **중앙값(Median) 대체** | 이상치(극단값)의 영향을 받지 않음 | 정규분포를 따르는 경우, 평균보다 대표성이 떨어질 수 있음 | **이상치가 많은 경우** |

# %% [markdown]
# **1.3 그로스 마케팅에서 결측값 처리 예제**
#
# **1.3.1 광고 데이터에서 결측값 처리**

# %%
# 광고 데이터 예제
ad_data = {
    "Campaign": ["YouTube Ad", "SNS Ad", "Search Ad", "Email Marketing", "SNS Ad"],
    "Impressions": [1000, 5000, np.nan, 7000, 3000],  # 결측값 포함
    "Clicks": [50, 200, 100, np.nan, 180],  # 결측값 포함
    "Conversions": [5, np.nan, 10, 20, 8]  # 결측값 포함
}

df_ad = pd.DataFrame(ad_data)

# 평균값으로 대체
df_ad["Impressions"].fillna(df_ad["Impressions"].mean())
df_ad["Clicks"].fillna(df_ad["Clicks"].mean())
df_ad["Conversions"].fillna(df_ad["Conversions"].mean())

print(df_ad)
# Out:
#           Campaign  Impressions  Clicks  Conversions
# 0       YouTube Ad       1000.0    50.0          5.0
# 1           SNS Ad       5000.0   200.0          NaN
# 2        Search Ad          NaN   100.0         10.0
# 3  Email Marketing       7000.0     NaN         20.0
# 4           SNS Ad       3000.0   180.0          8.0

# %% [markdown]
# **1.3.2 고객 데이터에서 결측값 처리**

# %%
# 고객 데이터 예제
customer_data = {
    "Customer ID": [101, 102, 103, 104, 105],
    "Age": [25, 30, np.nan, 40, 35],  # 결측값 포함
    "Purchase Amount": [100, 200, np.nan, 400, 300]  # 결측값 포함
}

df_customer = pd.DataFrame(customer_data)

# 중앙값으로 대체
df_customer["Age"].fillna(df_customer["Age"].median())
df_customer["Purchase Amount"].fillna(df_customer["Purchase Amount"].median())

print(df_customer)
# Out:
#    Customer ID   Age  Purchase Amount
# 0          101  25.0            100.0
# 1          102  30.0            200.0
# 2          103   NaN              NaN
# 3          104  40.0            400.0
# 4          105  35.0            300.0

# %% [markdown]
# 1. **결측값이 적고, 데이터가 정규 분포를 따르는 경우 평균(Mean)으로 대체하는 것이 적합**
#     - 광고 클릭 수, 전환율과 같은 **정량적 마케팅 데이터** 처리에 유용
# 2. **이상치가 많거나 데이터의 분포가 비대칭인 경우 중앙값(Median)으로 대체하는 것이 효과적**
#     - 고객의 지출 금액, 고객 연령 등 **이상치(극단값)의 영향을 받기 쉬운 데이터**에서 유용
# 3. **그로스 마케팅에서는 결측값 처리를 통해 데이터 품질을 개선하고, 광고 캠페인 성과 분석 및 고객 행동 예측의 정확성을 높일 수 있음**
#
# 결측값을 효과적으로 처리하면 **광고 성과 비교, 전환율 예측, 고객 세그먼트 분석 등이 더욱 정확해져 마케팅 전략 최적화 가능**

# %% [markdown]
# ###**2. 데이터 타입 변환 (Data Type Conversion)**
#
# 광고 시청 여부, 가입 여부 등의 **문자형 데이터를 숫자형으로 변환**하여 분석이 가능하도록 한다.
#
# **2.1 카테고리형 데이터를 숫자로 변환**

# %%
# 광고 시청 여부를 0과 1로 변환
df["Ad Viewed"] = ["Yes", "No", "Yes", "No", "Yes"]
df["Ad Viewed"] = df["Ad Viewed"].map({"Yes": 1, "No": 0})

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed
# 0      101       10.0             0.02          1
# 1      102       50.0             0.05          0
# 2      103        NaN             0.03          1
# 3      104       30.0              NaN          0
# 4      105       60.0             0.07          1

# %% [markdown]
# ###**3. 범주형 데이터 변환 (Categorical Data Encoding)**
#
# 광고 유형, 유입 경로, 고객 세그먼트 등 범주형 데이터를 분석하려면 **숫자로 변환**해야 한다.
#
# **3.1 원-핫 인코딩 (One-Hot Encoding)**

# %%
# 광고 캠페인 유형을 원-핫 인코딩으로 변환
df["Campaign"] = ["YouTube Ad", "SNS Ad", "Search Ad", "Email Marketing", "SNS Ad"]
df = pd.get_dummies(df, columns=["Campaign"])

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101       10.0             0.02          1                     False
# 1      102       50.0             0.05          0                     False
# 2      103        NaN             0.03          1                     False
# 3      104       30.0              NaN          0                      True
# 4      105       60.0             0.07          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad
# 0            False               False                 True
# 1             True               False                False
# 2            False                True                False
# 3            False               False                False
# 4             True               False                False

# %% [markdown]
# ###**4. 데이터 스케일링 (Data Scaling)**
#
# 광고 비용, 클릭 수, 전환율 등 값의 범위가 다르면 **데이터를 일정한 범위로 변환하여 비교 가능하도록** 한다.
#
# **4.1 정규화 (Normalization)**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[["Ad Clicks", "Conversion Rate"]] = scaler.fit_transform(df[["Ad Clicks", "Conversion Rate"]])

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101        0.0              0.0          1                     False
# 1      102        0.8              0.6          0                     False
# 2      103        NaN              0.2          1                     False
# 3      104        0.4              NaN          0                      True
# 4      105        1.0              1.0          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad
# 0            False               False                 True
# 1             True               False                False
# 2            False                True                False
# 3            False               False                False
# 4             True               False                False

# %% [markdown]
# **4.2 표준화 (Standardization)**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[["Ad Clicks", "Conversion Rate"]] = scaler.fit_transform(df[["Ad Clicks", "Conversion Rate"]])

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101  -1.432078        -1.171700          1                     False
# 1      102   0.650945         0.390567          0                     False
# 2      103        NaN        -0.650945          1                     False
# 3      104  -0.390567              NaN          0                      True
# 4      105   1.171700         1.432078          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad
# 0            False               False                 True
# 1             True               False                False
# 2            False                True                False
# 3            False               False                False
# 4             True               False                False

# %% [markdown]
# ###**5. 피처 엔지니어링 (Feature Engineering)**
#
# 데이터를 추가 변환하여 새로운 분석 변수를 생성할 수 있다.
#
# #### **5.1 고객 세그먼트화**

# %%
# 전환율이 0.05 이상이면 VIP 고객, 그렇지 않으면 일반 고객
df["Customer Segment"] = df["Conversion Rate"].apply(lambda x: "VIP" if x >= 0.05 else "Regular")

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101  -1.432078        -1.171700          1                     False
# 1      102   0.650945         0.390567          0                     False
# 2      103        NaN        -0.650945          1                     False
# 3      104  -0.390567              NaN          0                      True
# 4      105   1.171700         1.432078          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad Customer Segment
# 0            False               False                 True          Regular
# 1             True               False                False              VIP
# 2            False                True                False          Regular
# 3            False               False                False          Regular
# 4             True               False                False              VIP

# %% [markdown]
# ###**6. 로그 변환 (Log Transformation)**
#
# 광고 비용과 같은 값이 **극단적으로 큰 경우(이상치 포함)** 로그 변환을 사용하여 데이터를 안정화할 수 있다.
#
# **6.1 로그 변환 적용**

# %%
import numpy as np

# 광고 비용 데이터
df["Ad Cost"] = [100, 5000, 2000, 10000, 3000]

# 로그 변환 적용 (0 방지 위해 1 추가)
df["Log Ad Cost"] = np.log1p(df["Ad Cost"])

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101  -1.432078        -1.171700          1                     False
# 1      102   0.650945         0.390567          0                     False
# 2      103        NaN        -0.650945          1                     False
# 3      104  -0.390567              NaN          0                      True
# 4      105   1.171700         1.432078          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad Customer Segment  \
# 0            False               False                 True          Regular
# 1             True               False                False              VIP
# 2            False                True                False          Regular
# 3            False               False                False          Regular
# 4             True               False                False              VIP
#
#    Ad Cost  Log Ad Cost
# ...

# %% [markdown]
# ###**7. 날짜 데이터 변환 (Date Processing)**
#
# 광고 성과 데이터에서 날짜를 활용할 때, **요일, 주차, 월 등으로 변환**하면 분석에 유용하다.
#
# **7.1 날짜 데이터를 요일로 변환**

# %%
# 날짜 데이터 추가
df["Date"] = pd.to_datetime(["2024-02-01", "2024-02-02", "2024-02-03", "2024-02-04", "2024-02-05"])

# 요일 컬럼 추가
df["Day of Week"] = df["Date"].dt.day_name()

print(df)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101  -1.432078        -1.171700          1                     False
# 1      102   0.650945         0.390567          0                     False
# 2      103        NaN        -0.650945          1                     False
# 3      104  -0.390567              NaN          0                      True
# 4      105   1.171700         1.432078          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad Customer Segment  \
# 0            False               False                 True          Regular
# 1             True               False                False              VIP
# 2            False                True                False          Regular
# 3            False               False                False          Regular
# 4             True               False                False              VIP
#
# ...

# %% [markdown]
# ###**8. 이상치 처리 (Outlier Handling)**
#
# 클릭 수, 광고 비용 등이 **비정상적으로 높은 값(이상치)**일 경우, 처리해야 한다.
#
# **8.1 사분위 범위 (IQR, Interquartile Range) 이용한 이상치 제거**

# %%
# 이상치 탐지
Q1 = df["Ad Clicks"].quantile(0.25)
Q3 = df["Ad Clicks"].quantile(0.75)
IQR = Q3 - Q1

# 이상치 제거
df_filtered = df[(df["Ad Clicks"] >= Q1 - 1.5 * IQR) & (df["Ad Clicks"] <= Q3 + 1.5 * IQR)]

print(df_filtered)
# Out:
#    User ID  Ad Clicks  Conversion Rate  Ad Viewed  Campaign_Email Marketing  \
# 0      101  -1.432078        -1.171700          1                     False
# 1      102   0.650945         0.390567          0                     False
# 3      104  -0.390567              NaN          0                      True
# 4      105   1.171700         1.432078          1                     False
#
#    Campaign_SNS Ad  Campaign_Search Ad  Campaign_YouTube Ad Customer Segment  \
# 0            False               False                 True          Regular
# 1             True               False                False              VIP
# 3            False               False                False          Regular
# 4             True               False                False              VIP
#
#    Ad Cost  Log Ad Cost       Date Day of Week
# 0      100     4.615121 2024-02-01    Thursday
# 1     5000     8.517393 2024-02-02      Friday
# 3    10000     9.210440 2024-02-04      Sunday
# ...

# %% [markdown]
# ###**9. 마케팅 데이터 변환 후 분석 예시**
#
# #### **9.1 광고 채널별 전환율 비교**

# %%
# 광고 채널별 평균 전환율 계산
campaign_performance = df.groupby("Campaign")["Conversion Rate"].mean()
print(campaign_performance)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-98d0aab461f5> in <cell line: 0>()
#       1 # 광고 채널별 평균 전환율 계산
# ----> 2 campaign_performance = df.groupby("Campaign")["Conversion Rate"].mean()
#       3 print(campaign_performance)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %% [markdown]
# **9.2 고객 세그먼트별 평균 광고 클릭 수**

# %%
# VIP 고객과 일반 고객의 평균 광고 클릭 수 비교
df["Customer Segment"] = ["VIP", "Regular", "VIP", "Regular", "VIP"]

customer_segment_clicks = df.groupby("Customer Segment")["Ad Clicks"].mean()
print(customer_segment_clicks)
# Out:
# Customer Segment
# Regular    0.130189
# VIP       -0.130189
# Name: Ad Clicks, dtype: float64

# %% [markdown]
# ---
#
# ##**데이터 표준화 및 정규화 필요성**

# %% [markdown]
# 그로스 마케팅에서는 광고 효과 분석, 고객 행동 데이터 비교, 마케팅 성과 평가 등을 위해 다양한 데이터를 분석함
# 이러한 데이터는 값의 범위가 다르기 때문에, 효과적인 비교를 위해 **데이터 변환(Data Transformation)이 필수적**

# %% [markdown]
# **대표적인 데이터 변환 기법**
#
# - **정규화(Normalization)**: 데이터를 0과 1 사이의 범위로 변환하여 상대적인 크기를 조정
#
# - **표준화(Standardization)**: 데이터를 평균 0, 표준편차 1의 정규 분포 형태로 변환
#
# 데이터를 **표준화 또는 정규화하면 다음과 같은 장점**이 있음
#
# - 서로 다른 크기를 가진 변수를 동일한 기준으로 비교 가능
# - 머신러닝 모델 학습 시, 특정 변수에 영향을 크게 받는 문제 방지
# - 광고 캠페인 성과 분석에서 **광고 영향도, 클릭 수, 제품 만족도 등의 비교 가능**

# %% [markdown]
# ---
#
# ##**정규화 (Normalization)**

# %% [markdown]
# ### **2.1 정규화 개념**
#
# 정규화는 **데이터 값을 0~1 사이의 값으로 변환**하는 방법
#
# 대표적인 정규화 방식: **Min-Max Scaling**

# %% [markdown]
# **수식:**
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# **최소값을 0, 최대값을 1로 변환**, 모든 값이 동일한 범위 내에 존재하도록 함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위 그래프는 Min-Max 정규화를 적용한 결과를 시각화한 것.
#
# 원본 데이터(10, 50, 30, 80, 60)를 0~1 범위로 변환한 값을 그래프로 표현, 데이터가 선형적으로 정규화되는 과정을 확인 가능

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# 예제 데이터 (광고 영향도, 제품 만족도)
data = {
    "Ad Influence": [10, 50, 30, 80, 60],
    "Product Satisfaction": [2, 4, 3, 5, 4]
}

df = pd.DataFrame(data)

# Min-Max Scaling 적용
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

print("Original Data:\n", df)
print("\nNormalized Data:\n", df_normalized)
# Out:
# Original Data:
#     Ad Influence  Product Satisfaction
# 0            10                     2
# 1            50                     4
# 2            30                     3
# 3            80                     5
# 4            60                     4
#
# Normalized Data:
#     Ad Influence  Product Satisfaction
# 0      0.000000              0.000000
# 1      0.571429              0.666667
# 2      0.285714              0.333333
# 3      1.000000              1.000000
# 4      0.714286              0.666667

# %% [markdown]
# **정규화의 장점**
#
# - 데이터 값이 **0~1 범위로 변환**되어 비교가 용이
# - 특정 값이 다른 값보다 너무 커서 분석에 영향을 주는 문제 방지
# - **광고 효과, 구매율, 사용자 활동 데이터 분석에 적합**

# %% [markdown]
# ---
#
# ##**표준화 (Standardization)**

# %% [markdown]
# ### **3.1 표준화 개념**
#
# 표준화는 **데이터를 평균 0, 표준편차 1을 가지도록 변환**하는 방법
#
# 대표적인 표준화 방식: **Z-score Normalization**

# %% [markdown]
# **수식:**
#
# > ![image.png](data:image/png;base64,...)
# - $\mu$ = 평균
# - $\sigma$ = 표준편차

# %% [markdown]
# 표준화를 수행하면 데이터가 평균 0을 중심으로 분포되며, 이상치의 영향을 줄이는 효과가 있음
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. **왼쪽 그래프: 원본 데이터**
#     - 평균이 **50**, 표준편차가 **15**인 정규 분포 데이터를 생성하여 표현
#     - **파란색 히스토그램**은 원본 데이터의 분포를 나타내며, **빨간색 곡선**은 정규 분포(Gaussian Curve)를 시각적으로 표현
#     - 데이터의 중심이 평균 **50**에 모여 있고, 값들이 대칭적으로 퍼져 있음
# 2. **오른쪽 그래프: 표준화된 데이터**
#     - 원본 데이터에서 평균을 빼고, 표준편차로 나누어 **평균을 0, 표준편차를 1**로 변환
#     - **주황색 히스토그램**은 변환된 데이터의 분포를 나타내며, **빨간색 곡선**은 표준 정규 분포(Standard Gaussian Distribution)
#     - 변환 후 데이터의 중심이 **0**이 되었으며, 동일한 분포 형태를 유지하지만 스케일이 조정됨

# %% [markdown]
# **표준화 과정의 핵심**
#
# - 원본 데이터에서 **평균을 빼고, 표준편차로 나누면 항상 평균이 0**이 됨
# - 이를 통해 데이터의 상대적인 크기는 유지되면서 **다른 특성과 비교가 용이해지고, 머신러닝 모델이 더 잘 학습할 수 있는 구조로 변경**

# %%
from sklearn.preprocessing import StandardScaler

# Standard Scaling 적용
scaler = StandardScaler()
df_standardized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

print("Original Data:\n", df)
print("\nStandardized Data:\n", df_standardized)
# Out:
# Original Data:
#     Ad Influence  Product Satisfaction
# 0            10                     2
# 1            50                     4
# 2            30                     3
# 3            80                     5
# 4            60                     4
#
# Standardized Data:
#     Ad Influence  Product Satisfaction
# 0     -1.489691             -1.568929
# 1      0.165521              0.392232
# 2     -0.662085             -0.588348
# 3      1.406930              1.372813
# 4      0.579324              0.392232

# %% [markdown]
# **표준화의 장점**
#
# - 모든 데이터가 **평균 0, 표준편차 1을 갖도록 변환**되어 정규 분포를 따름
# - **광고 성과 분석, 고객 분류, 머신러닝 모델 입력 데이터로 적합**
# - 값의 크기에 영향받지 않고 **비율(상대적 차이)만으로 비교 가능**

# %% [markdown]
# ---
#
# ## **4. 표준화 vs 정규화 비교**

# %% [markdown]
# ### **1. 방식**
#
# - **정규화 (Normalization)**: 데이터의 최소값과 최대값을 기준으로 **0~1 범위**로 변환하는 방식.
# - **표준화 (Standardization)**: 데이터의 평균을 **0**, 표준편차를 **1**로 변환하여 **정규 분포 형태**로 조정하는 방식

# %% [markdown]
# ### **2. 공식**
#
# - **정규화 공식**
#
# > ![image.png](data:image/png;base64,...)
# 최소값(X_min)과 최대값(X_max) 사용하여 데이터를 0~1 범위로 조정

# %% [markdown]
# - **표준화 공식**
#
# > ![image.png](data:image/png;base64,...)
# 평균(μ)을 0, 표준편차(σ)를 1로 변환하여 정규 분포로 조정

# %% [markdown]
# ### **3. 특징**
#
# - **정규화**: 값의 크기를 조절하여 상대적 크기를 비교할 수 있도록 함
# - **표준화**: 평균 중심으로 데이터 분포를 조정하여 데이터가 정규 분포에 가깝도록 만듦
#
# ### **4. 사용처**
#
# - **정규화**: 값의 범위가 일정하고 상대적 비교가 중요한 경우 (예: 클릭률, 구매율)
# - **표준화**: 데이터가 정규 분포를 따르거나 다양한 크기의 데이터를 다룰 때 (예: 광고 예산, 판매량)
