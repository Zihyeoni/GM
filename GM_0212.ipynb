# %% [markdown]
# #Day8. 데이터분석 개론
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**MariaDB 초기 설정**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# ##**여러 테이블 다루기 - JOIN**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**JOIN 활용 예제**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**예제) FOREIGN KEY**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**1) 고객과 주문 정보 함께 조회 (INNER JOIN)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**2) 고객 정보 & 주문 내역 모두 가져오기 (LEFT JOIN)**
# - 주문이 없는 고객도 조회

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**3) 주문 내역 있는 고객만 조회 (RIGHT JOIN)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**4) 모든 고객과 주문 정보 조회 (FULL OUTER JOIN 대체, UNION)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**연습 문제**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####1. 학생과 수업 정보를 결합하여 각 학생이 듣는 수업의 과목명, 담당 교사 조회

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####2. 모든 학생을 포함하여 수업 정보 조회 (수업 듣지 않는 학생도 포함)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####3. 모든 수업을 포함하여 학생과 연결하고, 해당 수업을 듣는 학생이 없으면 NULL값 표시

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**고급 SQL - 집계 함수와 그룹화**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**1) 총 주문 개수 조회**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**2) 고객별 총 주문 개수 조회 (GROUP BY)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**3) 고객별 총 주문 금액 조회**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**4) 가장 비싼 주문 찾기**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**5) 주문이 가장 많은 고객 찾기**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**6) 특정 기간(예: 2024년 3~4월) 동안의 주문 금액 총합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**7) 월별 총 주문 수 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# #**UNION**

# %% [markdown]
# ###**UNION 특징**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**1) 여러 국가에서의 마케팅 성과 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**2) 이메일과 SNS 캠페인 반응 데이터 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**3) UNION ALL 사용하여 중복 포함**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**4) 여러 국가에서의 마케팅 매출별 성과 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**5) A/B 테스트 그룹 데이터 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**JOIN & UNION**
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**JOIN 활용한 그로스 마케팅**

# %% [markdown]
# ###**1. 고객 정보와 구매 데이터 JOIN하여 VIP 고객 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####customers & purchases 테이블 JOIN 후, 10만원 이상 구매한 고객(VIP) 찾음
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# ###**2. 이메일 캠페인 반응과 구매 데이터 연결**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ####특정 이메일 캠페인에서 10번 이상 클릭한 고객의 구매 데이터 결합하여 캠페인 성과 분석
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# ###**3. 유입 채널별 전환율 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**4. 장바구니 이탈 고객 찾기**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 장바구니에 상품 담았지만, 구매하지 않은 고객 식별하여 리마케팅 대상 선정
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**5. 마케팅 비용 대비 매출 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####캠페인별 투자 대비 수익(profit) 계산
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**UNION 활용한 그로스 마케팅**

# %% [markdown]
# ###**1. 이메일과 SNS 캠페인 반응 데이터 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**2. 여러 국가에서의 마케팅 성과 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**3. 웹사이트, 모바일 앱, 오프라인 구매 데이터 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 웹, 모바일 앱, 오프라인 구매 데이터를 통합하여 고객별 구매 경로 분석
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**4. A/B 테스트 그룹별 성과 비교**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ###**5. 여러 마케팅 채널별 ROI 통합**

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**그로스 마케팅에서의 활용**
# - **JOIN**: 고객 분석, 유입 경로별 전환율, 마케팅 비용 대비 수익 계산 등
# - **UNION**: 다채널 성과 분석, 국가별 데이터 비교, A/B 테스트 결과 비교 등
