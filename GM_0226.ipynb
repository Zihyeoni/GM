# %% [markdown]
# #Day18. 통계분석기초
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **마케팅 데이터의 주요 지표 분석**
# 마케팅 데이터 분석은 소비자 행동을 이해하고, 마케팅 전략을 최적화하며, 비즈니스 성과를 개선하는 데 중요한 역할을 함
# 주요 지표(Performance Metrics)를 통해 마케팅 캠페인의 효과성을 측정하고, 향후 전략을 수립하는 데 활용

# %% [markdown]
# ##**트래픽(Website Traffic) 관련 지표**
# 웹사이트 방문자는 마케팅 성과를 측정하는 핵심 요소

# %% [markdown]
# - **방문자 수 (Visitors)**
#     - 특정 기간 동안 웹사이트를 방문한 총 사용자 수
#     - **신규 방문자(New Visitors) vs. 재방문자(Returning Visitors)** 비교 분석 가능
# - **페이지뷰(Page Views)**
#     - 방문자가 특정 웹사이트에서 본 페이지 수
#     - 페이지뷰가 많을수록 사용자가 많은 콘텐츠를 소비했음을 의미
# - **세션(Session)**
#     - 사용자가 웹사이트를 방문해 특정 시간 동안 머무른 활동 단위
#     - 평균 세션 길이(Average Session Duration)를 분석해 사용자의 관심도를 평가
# - **이탈률 (Bounce Rate)**
#     - 방문자가 한 페이지를 본 후 바로 이탈하는 비율
#     - 이탈률이 높으면 콘텐츠 개선이 필요할 가능성이 있음

# %% [markdown]
# ## **전환(Conversion) 관련 지표**
#
# 마케팅의 궁극적인 목표는 방문자가 특정 행동(구매, 가입 등)을 하도록 유도하는 것입니다.
#
# - **전환율(Conversion Rate)**
#     - 방문자 중 실제 구매, 회원가입, 문의 등의 행동을 한 비율
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#
#     - 웹사이트, 랜딩 페이지, 광고 캠페인의 성과를 평가하는 핵심 지표
# - **이탈률(Exit Rate)**
#     - 특정 페이지에서 사용자가 웹사이트를 떠나는 비율
#     - 특정 페이지에서 이탈률이 높은 경우, UX/UI 개선 필요
# - **장바구니 이탈율 (Cart Abandonment Rate)**
#     - 전자상거래에서 구매 직전 단계까지 갔다가 결제하지 않고 이탈한 비율
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#
#   - 결제 프로세스 최적화를 통해 개선 가능

# %% [markdown]
# ## **광고 성과(Advertising Performance) 관련 지표**
#
# 디지털 광고(검색 광고, SNS 광고 등)의 효율성을 측정하는 데 중요한 요소입니다.
#
# - **클릭률 (Click-Through Rate, CTR)**
#     - 광고 노출 대비 클릭 수 비율
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - CTR이 높으면 광고가 효과적이라는 의미
# - **광고 비용 대비 매출 (Return on Ad Spend, ROAS)**
#     - 광고비 대비 매출 성과를 측정하는 지표
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - ROAS가 높을수록 광고 투자 대비 효과가 큼
# - **고객 획득 비용 (Customer Acquisition Cost, CAC)**
#     - 신규 고객 1명을 획득하는 데 소요된 비용
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - CAC가 낮을수록 마케팅 효율성이 높음

# %% [markdown]
# ## **고객 유지(Customer Retention) 관련 지표**
#
# 고객 유지율이 높은 기업은 장기적인 수익성을 확보할 수 있습니다.
#
# - **고객 유지율 (Customer Retention Rate, CRR)**
#     - 기존 고객이 계속해서 서비스를 이용하는 비율
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - 고객 경험 개선 및 충성도 프로그램 강화로 향상 가능
# - **반복 구매율 (Repeat Purchase Rate, RPR)**
#     - 고객이 제품을 한 번 이상 구매하는 비율
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - VIP 고객 프로그램을 활용해 증가 가능
# - **순추천고객지수 (Net Promoter Score, NPS)**
#     - 고객이 브랜드를 추천할 가능성을 평가하는 지표
#     - 일반적으로 0~10점 척도로 측정되며, 다음과 같이 분류됨:
#         - 0~6점: 비추천 고객 (Detractors)
#         - 7~8점: 중립 고객 (Passives)
#         - 9~10점: 추천 고객 (Promoters)
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - 높은 NPS는 브랜드 충성도가 높다는 의미

# %% [markdown]
# ## **소셜 미디어 성과(Social Media Performance) 관련 지표**
#
# SNS에서의 브랜드 인지도 및 소비자 반응을 측정하는 지표입니다.
#
# - **팔로워 증가율 (Follower Growth Rate)**
#     - 소셜 미디어 팔로워 수가 증가하는 속도를 측정
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#
# - **참여율 (Engagement Rate)**
#     - 사용자가 콘텐츠에 반응한 비율 (좋아요, 댓글, 공유 등)
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)
#     - 콘텐츠가 타겟 고객에게 얼마나 잘 도달했는지 평가 가능
# - **도달률 (Reach Rate)**
#     - 게시물이 얼마나 많은 사용자에게 도달했는지를 측정
#     - 계산식:
#     > ![image.png](data:image/png;base64,...)

# %% [markdown]
# 마케팅 데이터 분석에서 위와 같은 주요 지표를 활용하면 캠페인의 효과를 수치적으로 평가
# 각 지표를 종합적으로 분석하여 **"트래픽 증가 → 전환율 최적화 → 광고 효율성 개선 → 고객 유지 및 충성도 향상"** 선순환 구조를 구축하는 것이 중요
# 마케팅 목표에 맞는 주요 지표를 설정하고, 지속적으로 모니터링하며 최적화하는 것이 데이터 기반 마케팅의 핵심

# %% [markdown]
# ---
#
# ##**시나리오 1: 방문자 수와 페이지뷰 분석**

# %% [markdown]
# **시나리오 설명**
# 어느 전자상거래 사이트는 마케팅 캠페인(A/B 테스트)을 진행하면서 방문자 수와 페이지뷰 증가를 모니터링하고 있다. 캠페인 A와 B 중 어떤 것이 더 많은 방문자와 페이지뷰를 유도했는지 분석한다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 하드코딩된 방문자 및 페이지뷰 데이터
data_visits = {
    "Date": ["2025-01-01", "2025-01-02", "2025-01-03", "2025-01-04", "2025-01-05"],
    "Campaign": ["A", "A", "B", "B", "A"],
    "Visitors": [5000, 5200, 7000, 6800, 5500],
    "Page_Views": [12000, 13000, 18000, 17500, 12500]
}

df_visits = pd.DataFrame(data_visits)

# 데이터 출력
display(df_visits)

# 방문자 및 페이지뷰 시각화
plt.figure(figsize=(8, 5))
plt.plot(df_visits["Date"], df_visits["Visitors"], label="Visitors", marker="o", linestyle="dashed")
plt.plot(df_visits["Date"], df_visits["Page_Views"], label="Page Views", marker="s", linestyle="dotted")
plt.xlabel("Date")
plt.ylabel("Count")
plt.title("Visitors & Page Views per Campaign")
plt.legend()
plt.grid()
plt.show()
# Out:
#          Date Campaign  Visitors  Page_Views
# 0  2025-01-01        A      5000       12000
# 1  2025-01-02        A      5200       13000
# 2  2025-01-03        B      7000       18000
# 3  2025-01-04        B      6800       17500
# 4  2025-01-05        A      5500       12500

# %% [markdown]
# - 캠페인 A는 1, 2일에 방문자와 페이지뷰가 모두 증가하였으며, 5일에는 방문자 수는 증가하였지만 페이지뷰는 감소하는 추세를 보임
# - 캠페인 B는 3, 4일에 A보다 높은 방문자 수와 페이지뷰를 기록하였으나, 4일에 방문자 수와 페이지뷰가 감소하는 추세를 보임
# - 따라서 캠페인 B가 A보다 더 효과적으로 판단되나, 4일에 방문자 수와 페이지뷰가 감소한 원인을 분석하여 개선 필요

# %% [markdown]
# ## **시나리오 2: 전환율(Conversion Rate)과 광고비 분석**
#
# ### **시나리오 설명**
#
# 회사는 광고를 집행하면서 **광고비에 따라 전환율(Conversion Rate)이 얼마나 영향을 받는지** 분석하고 있다.
#
# **광고비가 많을수록 전환율이 증가하는가?**

# %%
# 하드코딩된 광고비 및 전환율 데이터
data_conversion = {
    "Date": ["2025-01-01", "2025-01-02", "2025-01-03", "2025-01-04", "2025-01-05"],
    "Ad_Spend ($)": [1000, 2000, 1500, 2500, 3000],
    "Conversion_Rate (%)": [2.5, 3.8, 3.0, 4.5, 5.2]
}

df_conversion = pd.DataFrame(data_conversion)

display(df_conversion)

# 광고비와 전환율 시각화
plt.figure(figsize=(8, 5))
plt.scatter(df_conversion["Ad_Spend ($)"], df_conversion["Conversion_Rate (%)"], color="red", alpha=0.7)
plt.xlabel("Ad Spend ($)")
plt.ylabel("Conversion Rate (%)")
plt.title("Ad Spend vs. Conversion Rate")
plt.grid()
plt.show()
# Out:
#          Date  Ad_Spend ($)  Conversion_Rate (%)
# 0  2025-01-01          1000                  2.5
# 1  2025-01-02          2000                  3.8
# 2  2025-01-03          1500                  3.0
# 3  2025-01-04          2500                  4.5
# 4  2025-01-05          3000                  5.2

# %% [markdown]
# - 광고비가 증가할수록 전환율도 함께 증가하는 것을 알 수 있음
# - 광고비 외에도 어떤 광고 프로모션이 전환율에 영향을 미칠지 분석하여 최적화 필요

# %% [markdown]
# ## **시나리오 3: ROAS(광고 수익률) 분석**
#
# ### **시나리오 설명**
#
# 회사는 광고 투자 대비 매출 성과(ROAS, Return on Ad Spend)를 측정하고 있다.
#
# **광고 비용을 늘릴수록 ROAS가 증가하는가?**

# %%
# 하드코딩된 광고비 및 ROAS 데이터
data_roas = {
    "Date": ["2025-01-01", "2025-01-02", "2025-01-03", "2025-01-04", "2025-01-05"],
    "Ad_Spend ($)": [1000, 2000, 3000, 4000, 5000],
    "Revenue ($)": [5000, 9000, 14000, 18000, 22000]
}

df_roas = pd.DataFrame(data_roas)

# ROAS 계산 추가
df_roas["ROAS"] = (df_roas["Revenue ($)"] / df_roas["Ad_Spend ($)"]).round(2)

display(df_roas)

# 광고비 대비 ROAS 시각화
plt.figure(figsize=(8, 5))
plt.plot(df_roas["Ad_Spend ($)"], df_roas["ROAS"], marker="o", linestyle="dashed", color="blue")
plt.xlabel("Ad Spend ($)")
plt.ylabel("ROAS")
plt.title("Ad Spend vs. ROAS")
plt.grid()
plt.show()
# Out:
#          Date  Ad_Spend ($)  Revenue ($)  ROAS
# 0  2025-01-01          1000         5000  5.00
# 1  2025-01-02          2000         9000  4.50
# 2  2025-01-03          3000        14000  4.67
# 3  2025-01-04          4000        18000  4.50
# 4  2025-01-05          5000        22000  4.40

# %% [markdown]
# - 광고비 1,000달러에서의 ROAS가 가장 높으며, 이후 광고비를 늘릴수록 감소하는 추세를 보임
# - 3,000달러에서 ROAS가 증가하는 것을 알 수 있음
# - 1,000 ~ 3,000달러를 투자하는 것이 가장 효율적일 것으로 판단됨
# - 광고비 외의 다른 요인들이 영향을 미친 것인지 확인해보고 A/B 테스트를 통해 비교 분석 후 개선 필요

# %% [markdown]
# ## **시나리오 4: 신규 고객 수와 CAC 분석**
#
# ### **시나리오 설명**
#
# 회사는 특정 기간 동안 **신규 고객 획득 비용(CAC, Customer Acquisition Cost)** 을 측정하고 있다.
#
# **광고비 대비 신규 고객 증가가 얼마나 효율적인가?**

# %%
# 하드코딩된 신규 고객 및 CAC 데이터
data_cac = {
    "Date": ["2025-01-01", "2025-01-02", "2025-01-03", "2025-01-04", "2025-01-05"],
    "New_Customers": [100, 200, 150, 250, 300],
    "Ad_Spend ($)": [2000, 4000, 3500, 5000, 6000]
}

df_cac = pd.DataFrame(data_cac)

# CAC 계산 추가
df_cac["CAC ($)"] = (df_cac["Ad_Spend ($)"] / df_cac["New_Customers"]).round(2)

display(df_cac)

# 신규 고객 수 대비 CAC 시각화
plt.figure(figsize=(8, 5))
plt.scatter(df_cac["New_Customers"], df_cac["CAC ($)"], color="green", alpha=0.7)
plt.xlabel("New Customers")
plt.ylabel("CAC ($)")
plt.title("New Customers vs. CAC")
plt.grid()
plt.show()
# Out:
#          Date  New_Customers  Ad_Spend ($)  CAC ($)
# 0  2025-01-01            100          2000    20.00
# 1  2025-01-02            200          4000    20.00
# 2  2025-01-03            150          3500    23.33
# 3  2025-01-04            250          5000    20.00
# 4  2025-01-05            300          6000    20.00

# %% [markdown]
# - 신규 고객 수가 150명일 때의 CAC가 23달러로 가장 높음 (비효율적)
# - 이를 제외한 경우에서는 CAC가 20달러로 동일함
# - 2025-01-03의 CAC 증가 원인을 분석하여 광고비를 재설정할 필요가 있음

# %% [markdown]
# ## **시나리오 5: SNS 팔로워 증가 분석**
#
# ### **시나리오 설명**
#
# 기업은 **SNS 마케팅 캠페인을 진행하면서 팔로워 증가율을 모니터링**하고 있다.
#
# **SNS 활동이 팔로워 증가에 효과적인가?**

# %%
# 하드코딩된 SNS 팔로워 증가 데이터
data_followers = {
    "Date": ["2025-01-01", "2025-01-02", "2025-01-03", "2025-01-04", "2025-01-05"],
    "Posts": [3, 4, 2, 5, 6],  # 하루 동안 올린 게시글 수
    "Followers_Growth": [50, 80, 45, 100, 120]  # 하루 동안 증가한 팔로워 수
}

df_followers = pd.DataFrame(data_followers)

display(df_followers)

# SNS 활동과 팔로워 증가율 시각화
plt.figure(figsize=(8, 5))
plt.scatter(df_followers["Posts"], df_followers["Followers_Growth"], color="purple", alpha=0.7)
plt.xlabel("Posts per Day")
plt.ylabel("Followers Growth")
plt.title("Posts vs. Followers Growth")
plt.grid()
plt.show()
# Out:
#          Date  Posts  Followers_Growth
# 0  2025-01-01      3                50
# 1  2025-01-02      4                80
# 2  2025-01-03      2                45
# 3  2025-01-04      5               100
# 4  2025-01-05      6               120

# %% [markdown]
# - 게시물 수가 증가함에 따라 팔로워 수도 증가하는 추세를 보임
# - 게시물 수 뿐만 아니라 게시물 콘텐츠, 외부 요인 등이 팔로워 증가에 영향을 미칠 수 있으므로 다른 요인들에 대한 분석도 필요

# %% [markdown]
# ---
#
# ##**주요지표 연습 & 보고서 작성**

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 63.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# CSV 파일 로드
csv_filename = "coupang.csv"
df = pd.read_csv(csv_filename)

# 데이터 확인
display(df)
print(df.info())  # 데이터 타입 및 결측값 확인
# Out:
#              날짜   마케팅 캠페인  방문자 수  페이지뷰 수  이탈률 (%)  전환율 (%)  광고비 ($)  매출 ($)  \
# 0    2024-01-01     Email  24915  189785    54.03     7.46    19350   68217
# 1    2024-01-02  Referral  44915  170806    37.03     8.88     1375   94044
# 2    2024-01-03  Paid Ads  42219   82588    69.47     1.65     1262   14045
# 3    2024-01-04  Referral  20343   73646    24.45     6.53    12580   25116
# 4    2024-01-05  Referral  43727   13654    33.58     6.03    11136   23667
# ..          ...       ...    ...     ...      ...      ...      ...     ...
# 995  2026-09-22       SNS  28171  172727    67.37     6.19    10327   79329
# 996  2026-09-23       SEO  39905   53472    37.81     6.70     6127    6620
# 997  2026-09-24       SEO  25829   59437    52.48     1.96    10065   67224
# 998  2026-09-25     Email  39054  190488    40.71     9.78    11492   61655
# 999  2026-09-26  Paid Ads  49139   69711    44.85     5.68    14749   42534
#
# ...

# %% [markdown]
# ###**주요지표 분석**

# %% [markdown]
# **1) 방문자 수 및 페이지뷰 트렌드**

# %%
plt.figure(figsize=(12, 5))
plt.plot(df["날짜"], df["방문자 수"], label="방문자 수", marker="o", linestyle="dashed")
plt.plot(df["날짜"], df["페이지뷰 수"], label="페이지뷰 수", marker="s", linestyle="dotted")
plt.xlabel("날짜")
plt.ylabel("수치")
plt.title("방문자 수 & 페이지뷰 트렌드")
plt.legend()
#plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# **2) 광고비 vs. ROAS 분석**

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["광고비 ($)"], df["광고 수익률 (ROAS)"], color="red", alpha=0.7)
plt.xlabel("광고비 ($)")
plt.ylabel("ROAS (광고 수익률)")
plt.title("광고비 vs ROAS")
plt.grid()
plt.show()

# %% [markdown]
# **3) 신규 고객 수 vs. CAC 분석**

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["신규 고객 수"], df["고객 획득 비용 (CAC)"], color="blue", alpha=0.7)
plt.xlabel("신규 고객 수")
plt.ylabel("CAC (고객 획득 비용)")
plt.title("신규 고객 수 vs CAC")
plt.grid()
plt.show()

# %% [markdown]
# **4) 마케팅 캠페인별 전환율 비교**

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="마케팅 캠페인", y="전환율 (%)", data=df)
plt.xlabel("마케팅 캠페인")
plt.ylabel("전환율 (%)")
plt.title("마케팅 캠페인별 전환율 비교")
plt.grid()
plt.show()

# %% [markdown]
# **5) 이탈률과 전환율 관계 분석**

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["이탈률 (%)"], df["전환율 (%)"], color="green", alpha=0.7)
plt.xlabel("이탈률 (%)")
plt.ylabel("전환율 (%)")
plt.title("이탈률 vs 전환율")
plt.grid()
plt.show()

# %% [markdown]
# ---
#
# ### **롯데온 데이터를 이용한 주요 지표 분석 연습**

# %%
df_lotteon = pd.read_csv("lotteon.csv", encoding='utf-8-sig')
display(df_lotteon)
print(df_lotteon.info())
# Out:
#              날짜   마케팅 캠페인  방문자 수  페이지뷰 수  이탈률 (%)  전환율 (%)  광고비 ($)  매출 ($)  \
# 0      2024.1.1     Email  36755  218375    33.18     4.73    19556   37719
# 1      2024.1.2  Referral  43390   19308    82.88     1.33    19076   46017
# 2      2024.1.3  Paid Ads  26711  248853    45.19     4.30    22974   49704
# 3      2024.1.4  Referral  29122  201594    39.33    11.78     2683   34013
# 4      2024.1.5  Referral  12160  184743    18.52     7.67    22651   83991
# ...         ...       ...    ...     ...      ...      ...      ...     ...
# 1995  2029.6.18       SEO  26303  129724    26.46     3.38     7458  145868
# 1996  2029.6.19  Referral  48280   70901    35.96     0.74     7136    7881
# 1997  2029.6.20       SEO  30606  115227    22.01     1.74    14696   19668
# 1998  2029.6.21  Referral  50832  208569    34.02    11.84    10430   32106
# 1999  2029.6.22  Paid Ads  31151  233885    72.12     3.99    18056   19729
#
# ...

# %% [markdown]
# **문제 1: 월별 방문자 수와 페이지뷰 수의 추세를 분석하세요.**

# %%
df_lotteon["날짜"] = pd.to_datetime(df_lotteon["날짜"], errors='coerce')
df_lotteon["월"] = df_lotteon["날짜"].dt.to_period("M")

monthly_group = df_lotteon.groupby("월")[["방문자 수", "페이지뷰 수"]].mean()

plt.figure(figsize=(12, 5))
plt.plot(monthly_group.index.astype(str), monthly_group['방문자 수'], label="방문자 수", marker='o', linestyle="dashed")
plt.plot(monthly_group.index.astype(str), monthly_group['페이지뷰 수'], label="페이지뷰 수", marker='s', linestyle="dotted")
plt.xlabel("날짜")
plt.ylabel("수치")
plt.title("월별 방문자 수 및 페이지뷰 수 추세")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# **문제 2: 마케팅 캠페인별 평균 전환율을 비교하세요.**

# %%
conversion_group = df_lotteon.groupby("마케팅 캠페인")["전환율 (%)"].mean().sort_values()

plt.figure(figsize=(10, 5))
sns.barplot(x=conversion_group.index, y=conversion_group.values, palette="Blues_r")
plt.xlabel("마케팅 캠페인")
plt.ylabel("평균 전환율 (%)")
plt.title("마케팅 캠페인별 평균 전환율 비교")
plt.grid()
plt.show()
# Out:
# <ipython-input-31-7bf5510ffe2f>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=conversion_group.index, y=conversion_group.values, palette="Blues_r")

# %% [markdown]
# **문제 3: 광고비가 증가할수록 ROAS(광고 수익률)가 증가하는지 확인하세요.**

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df_lotteon["광고비 ($)"], df_lotteon["광고 수익률 (ROAS)"], color='red', alpha=0.7)
plt.xlabel("광고비 ($)")
plt.ylabel("ROAS (광고 수익률)")
plt.title("광고비 vs ROAS")
plt.grid()
plt.show()

# %% [markdown]
# **문제 4: 신규 고객 수와 고객 획득 비용(CAC) 간의 관계를 분석하세요.**

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df_lotteon['신규 고객 수'], df_lotteon['고객 획득 비용 (CAC)'], color='blue', alpha=0.7)
plt.xlabel("신규 고객 수")
plt.ylabel("CAC (고객 획득 비용)")
plt.title("신규 고객 수 vs CAC")
plt.grid()
plt.show()

# %% [markdown]
# **문제 5: 이탈률(%)과 전환율(%)의 상관관계를 분석하세요.**

# %%
import numpy as np

correlation = np.corrcoef(df_lotteon['이탈률 (%)'], df_lotteon['전환율 (%)'])[0, 1]
print(f"이탈률과 전환율의 상관계수: {correlation:.2f}")

plt.figure(figsize=(8, 5))
plt.scatter(df_lotteon['이탈률 (%)'], df_lotteon['전환율 (%)'], color='green', alpha=0.7)
plt.xlabel("이탈률 (%)")
plt.ylabel("전환율 (%)")
plt.title("이탈률 vs 전환율")
plt.grid()
plt.show()
# Out:
# 이탈률과 전환율의 상관계수: 0.01

# %% [markdown]
# **문제 6: 클릭률(CTR)이 높은 캠페인과 낮은 캠페인을 비교하고, 평균 CTR을 구하세요.**

# %%
ctr_group = df_lotteon.groupby("마케팅 캠페인")["클릭률 (%)"].mean().sort_values()
print("평균 CTR:"), display(ctr_group)

plt.figure(figsize=(10, 5))
sns.barplot(x=ctr_group.index, y=ctr_group.values, palette="Reds_r")
plt.xlabel("마케팅 캠페인")
plt.ylabel("평균 클릭률 (%)")
plt.title("마케팅 캠페인별 평균 클릭률 비교")
plt.grid()
plt.show()
# Out:
# 평균 CTR:
# 마케팅 캠페인
# SEO         8.873301
# Referral    8.945575
# Paid Ads    9.081530
# SNS         9.535810
# Email       9.753157
# Name: 클릭률 (%), dtype: float64
# <ipython-input-51-e3265000c67d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ctr_group.index, y=ctr_group.values, palette="Reds_r")

# %% [markdown]
# **문제 7: 마케팅 캠페인별 ROAS(광고 수익률)의 차이를 분석하세요.**

# %%
roas_group = df_lotteon.groupby("마케팅 캠페인")["광고 수익률 (ROAS)"].mean().sort_values()

plt.figure(figsize=(10, 5))
sns.barplot(x=roas_group.index, y=roas_group.values, palette="Purples_r")
plt.xlabel("마케팅 캠페인")
plt.ylabel("평균 ROAS")
plt.title("마케팅 캠페인별 ROAS 비교")
plt.grid()
plt.show()
# Out:
# <ipython-input-37-36359931d33b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=roas_group.index, y=roas_group.values, palette="Purples_r")

# %% [markdown]
# **문제 8: 장바구니 이탈율이 높은 날짜와 낮은 날짜를 비교하여 원인을 분석하세요.**

# %%
high_abandonment = df_lotteon.sort_values(by="장바구니 이탈율 (%)", ascending=False).head()
low_abandonment = df_lotteon.sort_values(by="장바구니 이탈율 (%)", ascending=True).head()

print("장바구니 이탈률 높은 날짜:")
display(high_abandonment[["날짜", "장바구니 이탈율 (%)", "전환율 (%)", "광고비 ($)"]])

print("\n장바구니 이탈률 낮은 날짜:")
display(low_abandonment[["날짜", "장바구니 이탈율 (%)", "전환율 (%)", "광고비 ($)"]])
# Out:
# 장바구니 이탈률 높은 날짜:
#              날짜  장바구니 이탈율 (%)  전환율 (%)  광고비 ($)
# 734    2026.1.4         74.92     5.68    23570
# 86    2024.3.27         74.91     8.71     1227
# 1311   2027.8.4         74.88    10.92    22153
# 129    2024.5.9         74.88    11.86    11586
# 641   2025.10.3         74.87     6.61    18434
# 장바구니 이탈률 낮은 날짜:
#              날짜  장바구니 이탈율 (%)  전환율 (%)  광고비 ($)
# 209   2024.7.28          5.08     6.17    22614
# 975    2026.9.2          5.09     0.94    13817
# 1334  2027.8.27          5.10     8.13    12727
# 1910  2029.3.25          5.12     1.15    22951
# 834   2026.4.14          5.13     1.30    20844

# %% [markdown]
# **문제 9: SNS 팔로워 증가 수와 신규 고객 수의 관계를 분석하세요.**

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df_lotteon["SNS 팔로워 증가 수"], df_lotteon["신규 고객 수"], color='purple', alpha=0.7)
plt.xlabel("SNS 팔로워 증가 수")
plt.ylabel("신규 고객 수")
plt.title("SNS 팔로워 증가 수 vs 신규 고객 수")
plt.grid()
plt.show()

# %% [markdown]
# **문제 10: 월별 평균 방문자 수 및 전환율 변화를 분석하세요.**

# %%
monthly_avg = df_lotteon.groupby("월")[["방문자 수", "전환율 (%)"]].mean()

plt.figure(figsize=(12,5))
plt.plot(monthly_avg.index.astype(str), monthly_avg["방문자 수"], label="평균 방문자 수", marker='o')
plt.plot(monthly_avg.index.astype(str), monthly_avg["전환율 (%)"] * 1000, label="평균 전환율 (x1,000)", marker='s', linestyle='dashed')
plt.xlabel("월")
plt.ylabel("수치")
plt.title("월별 평균 방문자 수 및 전환율 변화")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ---
#
# ## **마케팅 보고서 예시 : 신세계몰(SHINSEGAE MALL)**

# %% [markdown]
# ### **시나리오: 신세계몰의 디지털 마케팅 성과 분석 및 개선 전략**
#
# **배경:**
#
# 신세계몰은 백화점 및 마트와 연계된 온라인 쇼핑몰로, 최근 온라인 시장의 경쟁 심화 속에서 **광고 효율성과 전환율 개선을 위한 전략**이 필요하다. 기존 고객 유지와 신규 고객 유입을 동시에 강화하는 것이 목표다.
#
# **과제:**
#
# 1. 방문자 수 증가에도 불구하고 **전환율이 낮아 수익성이 정체**되고 있음.
# 2. **광고비 대비 매출(ROAS)이 낮아 광고 예산을 효율적으로 재분배**할 필요가 있음.
# 3. **SNS 채널의 팔로워는 증가하지만 실제 구매 연결이 약함**.
# 4. **고객 이탈률이 높아 재구매율을 높이는 전략**이 필요함.

# %% [markdown]
# ---
#
# **1. 트래픽(Website Traffic) 분석 지표**
#
# - **방문자 수(Visitors)** → 일별/월별 방문자 수 변동 분석
# - **페이지뷰(Page Views)** → 방문자당 평균 페이지뷰 계산
# - **이탈률(Bounce Rate) (%)** → 방문자가 한 페이지만 보고 이탈한 비율 분석
#
#
#
# **2. 장바구니 및 구매 패턴 분석 지표**
#
# - **장바구니 이탈율(Cart Abandonment Rate) (%)**
#     - **장바구니 이탈 비율이 높은 날과 낮은 날 비교**
#     - **광고비 대비 장바구니 이탈율 변화 분석**
# - **신규 고객 수(New Customers)** → 일별 신규 고객 유입 트렌드 분석
#
#
#
# **3. 광고 성과(Advertising Performance) 분석 지표**
#
# - **광고비 (원)** → 캠페인별/일별 광고 지출 분석
# - **매출 (원)** → 광고 투자 대비 매출 성과 분석
# - **광고비 대비 매출(ROAS, Return on Ad Spend) 계산**
#     > ![image.png](data:image/png;base64,...)
#
#     - **ROAS가 높은 광고 캠페인과 낮은 캠페인 비교**
#     - **월별 평균 ROAS 추이 분석**
# - **클릭률(CTR, Click-Through Rate) (%)**
#     - **CTR이 높은 광고 캠페인과 낮은 캠페인 비교**
#
#
#
# **4. 고객 유지(Customer Retention) 분석 지표**
#
# - **고객 획득 비용(CAC, Customer Acquisition Cost) 계산**
#     > ![image.png](data:image/png;base64,...)
#
#     - **CAC가 높은 캠페인과 낮은 캠페인 비교**
#     - **월별 CAC 변화 분석**
#
#
#
# **5. 소셜 미디어 성과 분석 지표**
#
# - **SNS 팔로워 증가 수(Follower Growth Count)**
#     - **SNS 팔로워 증가 추이 분석**
#     - **광고 캠페인과 SNS 성장 간의 상관관계 분석**

# %% [markdown]
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_shinsegae = pd.read_csv("shinsegae_data.csv", encoding='utf-8-sig')

# 날짜 데이터 변환
df_shinsegae["날짜"] = pd.to_datetime(df_shinsegae["날짜"])
df_shinsegae["월"] = df_shinsegae["날짜"].dt.to_period("M")

# 데이터 요약 정보 출력
display(df_shinsegae)
print(df_shinsegae.info())

#  2. 분석 결과 저장용 딕셔너리
analysis_results = {}

#  3. 트래픽 분석
analysis_results["일평균 방문자 수"] = df_shinsegae["방문자 수"].mean()
analysis_results["일평균 페이지뷰"] = df_shinsegae["페이지뷰 수"].mean()
analysis_results["평균 이탈률 (%)"] = df_shinsegae["이탈률 (%)"].mean()

#  4. 장바구니 및 구매 패턴 분석
analysis_results["평균 장바구니 이탈율 (%)"] = df_shinsegae["장바구니 이탈율 (%)"].mean()
analysis_results["일평균 신규 고객 수"] = df_shinsegae["신규 고객 수"].mean()

#  5. 광고 성과 분석
analysis_results["총 광고비 (원)"] = df_shinsegae["광고비 (원)"].sum()
analysis_results["총 매출 (원)"] = df_shinsegae["매출 (원)"].sum()
analysis_results["평균 ROAS"] = (df_shinsegae["매출 (원)"] / df_shinsegae["광고비 (원)"]).mean()
analysis_results["평균 클릭률 (%)"] = df_shinsegae["클릭률 (%)"].mean()

#  6. 고객 획득 비용(CAC) 분석
df_shinsegae["CAC (원)"] = df_shinsegae["광고비 (원)"] / df_shinsegae["신규 고객 수"]
analysis_results["평균 CAC (원)"] = df_shinsegae["CAC (원)"].mean()

#  7. 소셜 미디어 성과 분석
analysis_results["평균 SNS 팔로워 증가 수"] = df_shinsegae["SNS 팔로워 증가 수"].mean()

#  8. 데이터 요약 출력
summary_df = pd.DataFrame(analysis_results, index=["값"])
print("마케팅 데이터 분석 요약:"), display(summary_df)

#  9. 데이터 시각화
#  방문자 수 및 페이지뷰 추이
plt.figure(figsize=(12, 5))
plt.plot(df["날짜"], df_shinsegae["방문자 수"], label="방문자 수", marker="o", linestyle="dashed")
plt.plot(df["날짜"], df_shinsegae["페이지뷰 수"], label="페이지뷰 수", marker="s", linestyle="dotted")
plt.xlabel("날짜")
plt.ylabel("수치")
plt.title("방문자 수 및 페이지뷰 추이")
plt.legend()
plt.grid()
plt.show()

#  월별 광고비 vs. 매출
monthly_data = df_shinsegae.groupby("월")[["광고비 (원)", "매출 (원)"]].sum()
monthly_data.plot(kind="bar", figsize=(12, 5))
plt.xlabel("월")
plt.ylabel("금액 (원)")
plt.title("월별 광고비 및 매출 비교")
plt.legend()
plt.grid()
plt.show()

#  ROAS 분포
plt.figure(figsize=(8, 5))
plt.hist(df_shinsegae["매출 (원)"] / df_shinsegae["광고비 (원)"], bins=20, color="blue", alpha=0.7)
plt.xlabel("ROAS")
plt.ylabel("빈도")
plt.title("ROAS 분포")
plt.grid()
plt.show()

#  SNS 팔로워 증가 추이
plt.figure(figsize=(12, 5))
plt.plot(df_shinsegae["날짜"], df_shinsegae["SNS 팔로워 증가 수"], label="SNS 팔로워 증가", marker="o", linestyle="dashed", color="purple")
plt.xlabel("날짜")
plt.ylabel("SNS 팔로워 증가 수")
plt.title("SNS 팔로워 증가 추이")
plt.legend()
plt.grid()
plt.show()
# Out:
#             날짜   마케팅 캠페인  방문자 수  페이지뷰 수  이탈률 (%)  전환율 (%)  신규 고객 수  \
# 0   2024-01-01     Email  24915   86635    69.56     2.53     2382
# 1   2024-01-02  Referral  44915  122803    57.36     6.82     2042
# 2   2024-01-03  Paid Ads  42219  231184    57.00     1.99     2293
# 3   2024-01-04  Referral  20343   50946    67.52     1.63      356
# 4   2024-01-05  Referral  51403   70204    30.15     7.76     1737
# ..         ...       ...    ...     ...      ...      ...      ...
# 995 2026-09-22       SNS  18994   64811    62.52     0.84      456
# 996 2026-09-23       SEO  28499   45447    37.23     9.31     1922
# 997 2026-09-24       SEO  28040  143046    21.54     2.53     1553
# 998 2026-09-25     Email  48320  230002    22.59     4.49     2319
# 999 2026-09-26  Paid Ads  21959  246109    27.11     0.59     1229
#
#      장바구니 이탈율 (%)  클릭률 (%)  SNS 팔로워 증가 수  광고 수익률 (ROAS)  고객 획득 비용 (CAC)  \
# 0           31.42     6.08           403           1.60            7.72
# ...

# %% [markdown]
# ---
#
# ## **1. 개요**
#
# 본 보고서는 신세계몰의 디지털 마케팅 데이터를 바탕으로 주요 성과 지표(트래픽, 전환율, 광고 성과, 고객 유지, SNS 성과)를 분석하고, 실질적인 성과 개선을 위한 전략을 제시하는 것을 목표로 한다.

# %% [markdown]
# ## **2. 주요 지표 분석**
#
# ### **2.1 트래픽(Website Traffic) 분석**
#
# ### **1) 방문자 수 및 페이지뷰(Page Views)**
#
# - 최근 3개월간 **일평균 방문자 수: 50,000명**, **페이지뷰: 180,000건**
# - 신규 방문자 비율 **60%**, 재방문자 비율 **40%**
# - 방문자 수는 증가하고 있으나, **세션 지속 시간(2분 45초)이 업계 평균(3분 30초)보다 낮음** → UX/UI 개선 필요
#
# ### **2) 이탈률(Bounce Rate) 분석**
#
# - **이탈률: 55%** (업계 평균 50%)
# - 주요 이탈 원인:
#     - 모바일 페이지 속도 저하
#     - 상품 추천 정확도 부족
#
# ### **3) 평균 세션 길이(Session Duration)**
#
# - 평균 세션 지속 시간: **2분 45초**
# - 모바일 사용자의 평균 체류 시간이 **1분 50초**로 더욱 짧음
# - UX 개선 및 상품 상세 페이지 최적화 필요

# %% [markdown]
# ### **2.2 전환(Conversion) 분석**
#
# ### **1) 전환율(Conversion Rate)**
#
# - 전체 전환율: **2.9%** (업계 평균 3.5%)
# - 캠페인별 전환율:
#     - SEO: 2.6%
#     - SNS 광고: 3.2%
#     - 유료 광고(Paid Ads): 4.0%
#     - 이메일 마케팅: 2.1%
#
# ### **2) 장바구니 이탈율(Cart Abandonment Rate)**
#
# - 평균 장바구니 이탈율: **52%**
# - 주요 원인:
#     - 배송비 부담(35%)
#     - 복잡한 체크아웃 과정(25%)
#     - 단순 탐색(20%)
#
# ### **3) 이탈률(Exit Rate)**
#
# - **결제 페이지에서의 이탈률 60%**
# - 개선 방안:
#     - 무료 배송 프로모션 제공
#     - 결제 과정 간소화

# %% [markdown]
# ### **2.3 광고 성과(Advertising Performance) 분석**
#
# ### **1) 광고비 대비 매출(ROAS)**
#
# - 광고 유형별 ROAS:
#     - Google Ads: **5.1**
#     - Facebook Ads: **3.6**
#     - Naver 키워드 광고: **6.2**
#     - YouTube 광고: **2.9**
# - **Naver 키워드 광고의 ROAS가 가장 높음**, 따라서 해당 채널에 대한 추가 투자 고려
#
# ### **2) 클릭률(CTR)**
#
# - 평균 CTR: **4.2%**
# - 광고 유형별 CTR:
#     - 검색 광고(SEO): 5.0%
#     - 디스플레이 광고: 3.5%
#     - SNS 광고: 4.1%
#
# ### **3) 고객 획득 비용(CAC)**
#
# - 평균 CAC: **$22**
#
# - SEO 기반 유입 CAC: **$17**
#
# - 유료 광고 CAC: **$28**

# %% [markdown]
# ### **2.4 고객 유지(Customer Retention) 분석**
#
# ### **1) 고객 유지율(Customer Retention Rate, CRR)**
#
# - **고객 유지율: 63%** (목표: 70%)
# - VIP 고객군 비율: **28%**
# - 개선 방안:
#     - VIP 회원 맞춤 혜택 제공
#     - 멤버십 서비스 강화
#
# ### **2) 순추천고객지수(Net Promoter Score, NPS)**
#
# - 전체 NPS 점수: **42점**
# - 주요 불만 사항:
#     - 고객 서비스 응답 속도
#     - 배송 지연

# %% [markdown]
# ### **2.5 소셜 미디어 성과(Social Media Performance) 분석**
#
# ### **1) 팔로워 증가율(Follower Growth Rate)**
#
# - 최근 3개월간 **SNS 팔로워 증가율: 14%**
# - 플랫폼별 성장률:
#     - 인스타그램: **16% 증가**
#     - 페이스북: **10% 증가**
#     - 유튜브: **12% 증가**
#
# ### **2) 콘텐츠 참여율(Engagement Rate)**
#
# - 평균 참여율: **3.8%**
# - 콘텐츠 유형별 참여율:
#     - 이미지 게시물: **3.2%**
#     - 동영상 콘텐츠: **5.5%**
#     - 스토리/릴스: **6.0%**

# %% [markdown]
# ##**3. 마케팅 전략 제언**
#
# | 개선 항목 | 실행 방안 | 목표 |
# | --- | --- | --- |
# | **이탈률 감소** | 페이지 속도 최적화, UX 개선 | 이탈률 10% 감소 |
# | **전환율 증가** | 무료 배송 프로모션, 간편 결제 도입 | 전환율 1.5% 증가 |
# | **광고 성과 최적화** | ROAS 높은 광고 채널 확대, YouTube 광고 축소 | ROAS 20% 향상 |
# | **고객 유지율 향상** | 정기구독 모델 도입, 리워드 프로그램 강화 | 고객 유지율 70% 달성 |
# | **SNS 성과 최적화** | 동영상 콘텐츠 중심 마케팅 | SNS 참여율 5% 증가 |

# %% [markdown]
# ## **4. 실행 계획 및 기대 효과**
#
# - **SEO 최적화**를 통해 신규 고객 획득 비용 절감
# - **SNS 광고 리마케팅 전략**을 통해 유입-전환율 상승
# - **결제 프로세스 간소화 및 UX 개선**으로 이탈률 감소
# - **VIP 멤버십 강화**로 고객 충성도 증가

# %% [markdown]
# ## **5. 결론**
#
# 본 분석을 통해 신세계몰의 **전환율과 고객 유지율을 향상시키고, 광고 효율성을 극대화하는 전략을 제안**했다.
#
# **디지털 마케팅 최적화를 통해 매출 증대 및 고객 만족도를 높이는 것이 핵심 목표**이며, 지속적인 데이터 분석과 트렌드 반영이 필요하다.
#
#  **주요 목표:**
#
# ✔ 전환율 **3.5% 이상 달성**
#
# ✔ ROAS **20% 이상 향상**
#
# ✔ 고객 유지율 **70% 도달**
#
# ✔ SNS 참여율 **5% 증가**
