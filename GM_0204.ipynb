# %% [markdown]
# #Day2. 데이터분석 개론
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Python Grammar**
#
# ## **변수 (Variable)**
# 데이터를 저장하기 위한 *메모리 공간*

# %% [markdown]
# - 변수 선언, 값 할당

# %%
# 변수 선언 및 값 할당
a = 10
b = 20.5
c = "Hello, Python!"

# 변수 출력
print(a)
print(b)
print(c)
# Out:
# 10
# 20.5
# Hello, Python!

# %% [markdown]
# - 변수 타입

# %%
# 정수형 변수
integer_var = 100
print(type(integer_var))

# 실수형 변수
float_var = 25.4
print(type(float_var))

# 문자열 변수
string_var = "Python"
print(type(string_var))

# 불리언 변수
bool_var = True
print(type(bool_var))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# - 변수 이름 규칙
#   -  영문자(대소문자 구분), 숫자, 밑줄(_)로 구성
#   - 숫자로 시작 X
#   - 공백 포함 X

# %%
# 올바른 변수 이름
name = "Sumi"
age = 30
total_price = 45.78
is_valid = True

# 잘못된 변수 이름 (주석 처리된 부분은 에러 발생)
# 1st_name = "Sumi"  # 숫자로 시작할 수 없음
# user name = "Charls"   # 공백을 포함할 수 없음

# %% [markdown]
# - 변수 값 변경

# %%
# 변수 값 변경
counter = 10
print(counter)

counter = 15
print(counter)

counter = counter + 5
print(counter)
# Out:
# 10
# 15
# 20

# %% [markdown]
# - 여러 변수 한 번에 값 할당

# %%
# 여러 변수에 한 번에 값 할당
x, y, z = 1, 2, 3
print(x, y, z)

# 동일한 값을 여러 변수에 할당
a = b = c = 100
print(a, b, c)
# Out:
# 1 2 3
# 100 100 100

# %% [markdown]
# - 변수 삭제 (del)

# %%
# 변수 삭제
var = 10
print(var)

del var
print(var)  # 에러 발생: NameError: name 'var' is not defined
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6fedf944e0d2> in <cell line: 0>()
#       4
#       5 del var
# ----> 6 print(var)  # 에러 발생: NameError: name 'var' is not defined
#
# NameError: name 'var' is not defined

# %%
# 예제) 두 숫자 입력받기

num1 = float(input("첫 번째 숫자를 입력하세요: "))
num2 = float(input("두 번째 숫자를 입력하세요: "))

# 사칙연산 수행
sum_result = num1 + num2
diff_result = num1 - num2
prod_result = num1 * num2
quot_result = num1 / num2

# 결과 출력
print(f"덧셈 결과: {sum_result}")
print(f"뺄셈 결과: {diff_result}")
print(f"곱셈 결과: {prod_result}")
print(f"나눗셈 결과: {quot_result}")
# Out:
# 첫 번째 숫자를 입력하세요: 10
# 두 번째 숫자를 입력하세요: 30
# 덧셈 결과: 40.0
# 뺄셈 결과: -20.0
# 곱셈 결과: 300.0
# 나눗셈 결과: 0.3333333333333333

# %% [markdown]
# ---
#
#
# #### **연습문제**

# %% [markdown]
# 변수 선언과 값 할당) 두 개의 변수를 선언하고 각각 5와 10의 값을 할당한 후, 두 변수의 합을 출력하세요.

# %%
a, b = 5, 10
sum = a + b

print(sum)
# Out:
# 15

# %% [markdown]
# 변수 타입 확인) 정수, 실수, 문자열, 불리언 타입의 변수를 각각 하나씩 선언하고, 각 변수의 타입을 출력하세요.

# %%
int1 = 10
flo = 5.5
str1 = "Hyun Ji"
bool = True

print(type(int1))
print(type(flo))
print(type(str1))
print(type(bool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# 변수 값 변경) 변수 x에 20을 할당하고, 이를 두 배로 증가시킨 후 결과를 출력하세요.

# %%
x = 20
x = x * 2

print(x)
# Out:
# 40

# %% [markdown]
# 여러 변수에 한 번에 값 할당) a, b, c 세 개의 변수에 각각 1, 2, 3의 값을 한 번에 할당하고 이를 출력하세요.

# %%
a, b, c = 1, 2, 3

print(a, b, c)
# Out:
# 1 2 3

# %% [markdown]
# 동일한 값을 여러 변수에 할당) m, n, o 세 개의 변수에 모두 50의 값을 할당하고 이를 출력하세요.

# %%
m = n = o = 50

print(m, n, o)
# Out:
# 50 50 50

# %% [markdown]
# 변수 삭제) 변수 temp에 100을 할당하고 이를 삭제한 후, 삭제된 변수를 출력하려고 할 때 발생하는 에러를 확인하세요.

# %%
temp = 100
print(temp)

del temp
print(temp)
# Out:
# 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-88b890c3b076> in <cell line: 0>()
#       3
#       4 del temp
# ----> 5 print(temp)
#
# NameError: name 'temp' is not defined

# %% [markdown]
# 변수 이름 규칙) 변수 이름으로 사용할 수 없는 예를 찾아서 그 이유를 설명하세요.

# %%
# 2nd_var = 20 # 숫자로 시작할 수 없음
# my name = "HyunJi" # 공백 포함할 수 없음
# &value = 10 # 특수문자 & 사용 불가

# %% [markdown]
# 사칙연산) 두 변수 num1과 num2에 각각 15와 4를 할당한 후, 덧셈, 뺄셈, 곱셈, 나눗셈 결과를 출력하세요.

# %%
num1 = 15
num2 = 4

sum = num1 + num2
diff = num1 - num2
prod = num1 * num2
quot = num1 / num2

print(f"덧셈 결과: {sum}")
print(f"뺄셈 결과: {diff}")
print(f"곱셈 결과: {prod}")
print(f"나눗셈 결과: {quot}")
# Out:
# 덧셈 결과: 19
# 뺄셈 결과: 11
# 곱셈 결과: 60
# 나눗셈 결과: 3.75

# %% [markdown]
# 사용자 입력 받기) 사용자가 입력한 두 숫자를 변수 a와 b에 저장하고, 두 변수의 곱을 출력하세요.

# %%
num1 = float(input("첫번째 숫자를 입력하시오: "))
num2 = float(input("두번째 숫자를 입력하시오: "))

prod = num1 * num2
print(f"곱셈 결과: {prod}")
# Out:
# 첫번째 숫자를 입력하시오: 30
# 두번째 숫자를 입력하시오: 50
# 곱셈 결과: 1500.0

# %% [markdown]
# 문자열 결합) 두 개의 문자열 변수를 선언하고, 이들을 결합하여 출력하세요.

# %%
str1 = "Hello"
str2 = "HyunJi"

str3 = str1 + " " + str2
print(str3)
# Out:
# Hello HyunJi

# %% [markdown]
# ---
#
#
# ##**내장 자료형 (Built in Data type)**
#
# #### 수치형 (Numeric Types)

# %% [markdown]
# - **정수 Integer**

# %%
x = 10
y = -5

# %% [markdown]
# - **부동 소수정 Float**

# %%
x = 10.5
y = -2.75

# %% [markdown]
# - **복소수 Complex**

# %%
z = 3 + 4j

# %% [markdown]
# #### 시퀀스형 (Sequence Types)

# %% [markdown]
# - **문자열 String**

# %%
text = "Hello, World!"

# %% [markdown]
# - **리스트 List** (순서 o, 변경 가능)

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# - **튜플 Tuple** (순서 o, 변경 불가능)

# %%
fruits = ("apple", "banana", "cherry")
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# - **세트 Set** (순서 X, 중복 X)

# %%
fruits_set = {"apple", "banana", "cherry"}
fruits_set.add("orange")
print(fruits_set)
# Out:
# {'orange', 'cherry', 'banana', 'apple'}

# %% [markdown]
# #### 매핑형 (Mapping Types)

# %% [markdown]
# - **딕셔너리 Dictionary** (키-값 쌍의 집합)

# %%
person = {"name": "Alice", "age": 30, "city": "New York"}
person["job"] = "Engineer"
print(person)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York', 'job': 'Engineer'}

# %% [markdown]
# #### 부울형 (Boolean Type)

# %%
is_sunny = True
is_raining = False
print(is_sunny, is_raining)
# Out:
# True False

# %% [markdown]
# #### None 타입

# %%
x = None
print(x)
# Out:
# None

# %% [markdown]
# ---
#
# #### **연습문제**

# %% [markdown]
# 리스트 문제) 정수 1, 2, 3, 4, 5를 포함하는 리스트를 생성하고, 길이를 출력한 후 세 번째 요소를 10으로 변경하고 리스트를 출력하세요.

# %%
list = [1, 2, 3, 4, 5]
print(len(list))

list[2] = 10
print(list)
# Out:
# 5
# [1, 2, 10, 4, 5]

# %% [markdown]
# 튜플 문제) 문자열 "apple", "banana", "cherry"를 포함하는 튜플을 생성하고, 두 번째 요소를 출력하세요.

# %%
tuple = ("apple", "banana", "cherry")

print(tuple[1])
# Out:
# banana

# %% [markdown]
# 딕셔너리 문제) "name"을 키로 "Alice", "age"를 키로 30을 가지는 딕셔너리를 생성하고 "city" 키를 추가하여 "New York"을 설정한 후 출력하세요.

# %%
dict = {"name":"Alice", "age":30}
dict["city"] = "New York"
print(dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %% [markdown]
# 세트 문제) "apple", "banana", "cherry"를 포함하는 세트를 생성하고 "orange"를 추가한 후 "banana"를 제거하고 세트를 출력하세요.

# %%
set = {"apple", "banana", "cherry"}
set.add("orange")
set.remove("banana")
print(set)
# Out:
# {'orange', 'cherry', 'apple'}

# %% [markdown]
# 문자열 문제) 문자열 "Python is fun"을 변수에 저장하고 길이를 출력한 후 공백 기준으로 분리하여 리스트로 변환하고 출력하세요.

# %%
str1 = "Python is fun"
print(len(str1))

words = str1.strip()
print(words)
# Out:
# 13
# Python is fun

# %% [markdown]
# 정수와 부동 소수점 문제) 두 개의 정수형 변수 a와 b를 생성하고 두 변수의 합과 곱을 출력한 후 두 개의 부동 소수점 변수 x와 y를 생성하고 두 변수의 차이와 나눗셈 결과를 출력하세요.

# %%
a, b = 10, 30
sum = a + b
prod = a * b
print(f"합: {sum}, 곱: {prod}")

x, y = 10.0, 2.5
diff = x - y
quot = x / y
print(f"차이: {diff}, 나눗셈: {quot}")
# Out:
# 합: 40, 곱: 300
# 차이: 7.5, 나눗셈: 4.0

# %% [markdown]
# 복소수 문제) 복소수 3 + 4j를 변수 z에 저장하고 z의 실수부와 허수부를 각각 출력한 후 또 다른 복소수 1 - 2j를 생성하고 두 복소수의 합과 곱을 출력하세요.

# %%
z = 3 + 4j
print(z.real, z.imag)

z2 = 1 - 2j
print(f"합:{z + z2}, 곱:{z * z2}")
# Out:
# 3.0 4.0
# 합:(4+2j), 곱:(11-2j)

# %% [markdown]
# 부울형 문제) 변수 is_raining을 True로 설정하고 is_sunny를 False로 설정한 후 두 변수를 AND와 OR 연산자로 비교한 결과를 각각 출력하세요.

# %%
is_raining = True
is_sunny = False

print(is_raining and is_sunny)
print(is_raining or is_sunny)
# Out:
# False
# True

# %% [markdown]
# None 타입 문제) 변수 x에 None을 할당하고 x가 None인지 확인하는 조건문을 작성하여 조건이 참일 경우 "x is None"을 출력하세요.

# %%
x = None

if x is None:
  print("x is None")
# Out:
# x is None

# %% [markdown]
# 자료형 변환 문제) 정수 100을 문자열로 변환하고 결과를 출력한 후 문자열 "3.14"를 부동 소수점으로 변환하고 결과를 출력하세요.

# %%
num = 100
to_str = str(num)
print(to_str)

pi_str = 3.14
to_flo = float(pi_str)
print(to_flo)
# Out:
# 100
# 3.14

# %% [markdown]
# ---
#
# ## **조건문 (Conditional Statements)**

# %% [markdown]
# - 기본적인 if문

# %%
x = 10

if x > 5:
    print("x는 5보다 큽니다.")
# Out:
# x는 5보다 큽니다.

# %% [markdown]
# - if-else 문

# %%
x = 3

if x > 5:
    print("x는 5보다 큽니다.")
else:
    print("x는 5보다 작거나 같습니다.")
# Out:
# x는 5보다 작거나 같습니다.

# %% [markdown]
# - if-elif-else 문

# %%
x = 7

if x > 10:
    print("x는 10보다 큽니다.")
elif x > 5:
    print("x는 5보다 큽니다.")
else:
    print("x는 5보다 작거나 같습니다.")
# Out:
# x는 5보다 큽니다.

# %% [markdown]
# - 중첩된 조건문

# %%
x = 8
y = 6

if x > 5:
    if y > 5:
        print("x와 y는 모두 5보다 큽니다.")
    else:
        print("x는 5보다 크지만 y는 5보다 작습니다.")
else:
    print("x는 5보다 작습니다.")
# Out:
# x와 y는 모두 5보다 큽니다.

# %% [markdown]
# - 논리 연산자(and, or, not)와 함께 사용하는 조건문

# %%
x = 4
y = 10

if x > 3 and y > 5:
    print("x는 3보다 크고 y는 5보다 큽니다.")

if x > 5 or y > 5:
    print("x 또는 y 중 하나는 5보다 큽니다.")

if not x > 5:
    print("x는 5보다 크지 않습니다.")
# Out:
# x는 3보다 크고 y는 5보다 큽니다.
# x 또는 y 중 하나는 5보다 큽니다.
# x는 5보다 크지 않습니다.

# %% [markdown]
# - 비교 연산자와 함께 사용하는 조건문
#
# > ![image.png](data:image/png;base64,...)

# %%
a = 10
b = 20

if a == b:
    print("a와 b는 같습니다.")
elif a != b:
    print("a와 b는 다릅니다.")

if a < b:
    print("a는 b보다 작습니다.")

if a <= b:
    print("a는 b보다 작거나 같습니다.")

if a > b:
    print("a는 b보다 큽니다.")

if a >= b:
    print("a는 b보다 크거나 같습니다.")
# Out:
# a와 b는 다릅니다.
# a는 b보다 작습니다.
# a는 b보다 작거나 같습니다.

# %% [markdown]
# ---
#
# #### **연습문제**

# %% [markdown]
# 사용자로부터 숫자 하나를 입력받고, 그 숫자가 양수인지, 음수인지, 0인지 출력하는 프로그램을 작성하세요.

# %%
num = float(input("숫자를 입력하시오: "))

if num > 0:
  print("양수입니다.")
elif num < 0:
  print("음수입니다.")
else:
  print("0 입니다.")
# Out:
# 숫자를 입력하시오: 5
# 양수입니다.

# %% [markdown]
# 사용자로부터 숫자 하나를 입력받고, 그 숫자가 짝수인지 홀수인지 출력하는 프로그램을 작성하세요.

# %%
num = float(input("숫자를 입력하시오: "))

if num % 2 == 0:
  print("짝수입니다.")
else:
  print("홀수입니다.")
# Out:
# 숫자를 입력하시오: 15
# 홀수입니다.

# %% [markdown]
# 사용자로부터 나이를 입력받아 어린이(12세 이하), 청소년(13-19세), 성인(20세 이상)으로 분류하여 출력하는 프로그램을 작성하세요.

# %%
age = int(input("나이를 입력하시오: "))

if 0 <= age <= 12:
  print("어린이 입니다.")
elif 13 <= age <= 19:
  print("청소년 입니다.")
elif age >= 20:
  print("성인 입니다.")
else:
  print("올바른 입력값이 아닙니다.")
# Out:
# 나이를 입력하시오: 24
# 성인 입니다.

# %% [markdown]
# 사용자로부터 점수를 입력받아 90점 이상이면 A, 80점 이상이면 B, 70점 이상이면 C, 60점 이상이면 D, 그 외는 F를 출력하는 프로그램을 작성하세요.
#
# > ![image.png](data:image/png;base64,...)

# %%
score = float(input("점수를 입력하시오: "))

if score >= 90:
  print("A등급")
elif score >= 80:
  print("B등급")
elif score >= 70:
  print("C등급")
elif score >= 60:
  print("D등급")
else:
  print("F등급")
# Out:
# 점수를 입력하시오: 85
# B등급

# %% [markdown]
# 사용자로부터 세 개의 숫자를 입력받아 그 중 가장 큰 수를 출력하는 프로그램을 작성하세요.

# %%
num1 = float(input("1번째 숫자: "))
num2 = float(input("2번째 숫자: "))
num3 = float(input("3번째 숫자: "))

if num1 >= num2 and num1 >= num3:
  print(f"가장 큰 수는 {num1}입니다.")
elif num2 >= num1 and num2 >= num3:
  print(f"가장 큰 수는 {num2}입니다.")
else:
  print(f"가장 큰 수는 {num3}입니다.")
# Out:
# 1번째 숫자: 2
# 2번째 숫자: 10
# 3번째 숫자: 7
# 가장 큰 수는 10.0입니다.

# %% [markdown]
# 사용자로부터 월을 입력받아 봄(3-5월), 여름(6-8월), 가을(9-11월), 겨울(12-2월) 중 해당하는 계절을 출력하는 프로그램을 작성하세요.

# %%
month = int(input("월을 입력하시오: "))

if 3 <= month <= 5:
  print(f"{month}월은 봄입니다.")
elif 6 <= month <= 8:
  print(f"{month}월은 여름입니다.")
elif 9 <= month <= 11:
  print(f"{month}월은 가을입니다.")
elif month in [12, 1, 2]:
  print(f"{month}월은 겨울입니다.")
else:
  print("올바른 입력값이 아닙니다.")
# Out:
# 월을 입력하시오: 2
# 2월은 겨울입니다.

# %% [markdown]
# 사용자로부터 키(m)와 몸무게(kg)를 입력받아 BMI를 계산하고, 저체중(BMI < 18.5), 정상(BMI 18.5-24.9), 과체중(BMI 25-29.9), 비만(BMI 30 이상) 중 해당하는 범위를 출력하는 프로그램을 작성하세요.

# %%
height = float(input("키(m)를 입력하시오: "))
weight = float(input("몸무게(kg)를 입력하시오: "))
bmi = weight / (height ** 2)

if bmi < 18.5:
  print("저체중 입니다.")
elif bmi < 25:
  print("정상 입니다.")
elif bmi < 30:
  print("과체중 입니다.")
else:
  print("비만 입니다.")
# Out:
# 키(m)를 입력하시오: 1.6
# 몸무게(kg)를 입력하시오: 50
# 정상 입니다.

# %% [markdown]
# 사용자로부터 연도를 입력받아 그 연도가 윤년인지 아닌지 출력하는 프로그램을 작성하세요.

# %%
year = int(input("연도를 입력하시오: "))

if (year % 4 ==0 and year % 100 != 0) or (year % 400 == 0):
  print(f"{year}년은 윤년입니다.")
else:
  print(f"{year}년은 윤년이 아닙니다.")
# Out:
# 연도를 입력하시오: 2025
# 2025년은 윤년이 아닙니다.

# %% [markdown]
# 사용자로부터 구매 금액과 지불 금액을 입력받아 거스름돈을 계산하고, 부족한 경우에는 부족한 금액을 출력하는 프로그램을 작성하세요.

# %%
purchase = int(input("구매 금액을 입력하시오: "))
payment = int(input("지불 금액을 입력하시오: "))

if payment >= purchase:
  change = payment - purchase
  print(f"거스름돈은 {change}원입니다.")
else:
  shortage = purchase - payment
  print(f"부족한 금액은 {shortage}원입니다.")
# Out:
# 구매 금액을 입력하시오: 3000
# 지불 금액을 입력하시오: 1500
# 부족한 금액은 1500원입니다.

# %% [markdown]
# 사용자로부터 두 번 비밀번호를 입력받아 두 비밀번호가 일치하는지 여부를 출력하는 프로그램을 작성하세요.

# %%
password = input("비밀번호를 입력하시오: ")
re_password = input("비밀번호를 다시 한번 입력하시오: ")

if password == re_password:
  print("두 비밀번호가 일치합니다.")
else:
  print("두 비밀번호가 일치하지 않습니다.")
# Out:
# 비밀번호를 입력하시오: lhj422
# 비밀번호를 다시 한번 입력하시오: lhj22
# 두 비밀번호가 일치하지 않습니다.

# %% [markdown]
# ---
#
#
# ### **1. 광고비 대비 전환율 평가**
# 광고비와 전환율 데이터 활용하여 광고 캠페인의 성과 평가

# %%
ad_spend = 700000  # 광고비 (원)
conversion_rate = 0.03  # 전환율 (3%)

# 전환율 기준 평가
if conversion_rate >= 0.05:
    print("전환율이 우수합니다. 광고 전략을 유지하세요.")
elif 0.03 <= conversion_rate < 0.05:
    print("전환율이 보통입니다. 최적화를 고려하세요.")
else:
    print("전환율이 낮습니다. 광고 전략을 개선하세요.")
# Out:
# 전환율이 보통입니다. 최적화를 고려하세요.

# %% [markdown]
# ### **2. A/B 테스트 결과 비교**
# 두 개의 광고 캠페인 결과 비교, 더 나은 캠페인 선택

# %%
conversion_A = 0.045  # A 캠페인 전환율
conversion_B = 0.052  # B 캠페인 전환율

# 조건문을 활용한 비교
if conversion_A > conversion_B:
    print("A 캠페인이 더 우수합니다.")
elif conversion_A < conversion_B:
    print("B 캠페인이 더 우수합니다.")
else:
    print("두 캠페인의 성과가 동일합니다.")
# Out:
# B 캠페인이 더 우수합니다.

# %% [markdown]
# ### **3. 고객당 평균 구매 금액(ARPU) 계산**

# %%
total_revenue = 15000000  # 총 매출 (원)
total_customers = 300  # 총 고객 수

# 조건문을 활용한 ARPU 계산
if total_customers > 0:
    arpu = total_revenue / total_customers
    print(f"고객당 평균 구매 금액은 {arpu:,.0f} 원입니다.")
else:
    print("고객 수가 0명이므로 ARPU를 계산할 수 없습니다.")
# Out:
# 고객당 평균 구매 금액은 50,000 원입니다.

# %% [markdown]
# ### **4. 방문자 수 대비 구매율 분석**

# %%
total_visitors = 5000  # 방문자 수
total_buyers = 250  # 실제 구매자 수

# 구매율 계산 및 분석
if total_visitors > 0:
    purchase_rate = (total_buyers / total_visitors) * 100
    print(f"구매율: {purchase_rate:.2f}%")

    if purchase_rate >= 5:
        print("구매율이 우수합니다.")
    elif 2 <= purchase_rate < 5:
        print("구매율이 평균 수준입니다.")
    else:
        print("구매율이 낮습니다. 마케팅 전략을 조정하세요.")
else:
    print("방문자 수가 0이므로 구매율을 계산할 수 없습니다.")
# Out:
# 구매율: 5.00%
# 구매율이 우수합니다.

# %% [markdown]
# ### **5. ROAS(광고 수익률) 분석**

# %%
ad_spend = 800000  # 광고비 (원)
revenue = 4000000  # 광고를 통해 발생한 매출 (원)

# ROAS 계산 및 평가
if ad_spend > 0:
    roas = (revenue / ad_spend) * 100
    print(f"ROAS: {roas:.2f}%")

    if roas >= 400:
        print("ROAS가 우수합니다. 광고 전략을 유지하세요.")
    elif 200 <= roas < 400:
        print("ROAS가 평균 수준입니다. 개선할 여지가 있습니다.")
    else:
        print("ROAS가 낮습니다. 광고 전략을 조정하세요.")
else:
    print("광고비가 0원이므로 ROAS를 계산할 수 없습니다.")
# Out:
# ROAS: 500.00%
# ROAS가 우수합니다. 광고 전략을 유지하세요.

# %% [markdown]
# ### **6. 고객 세그먼트별 맞춤 할인 적용**

# %%
customer_name = "김철수"
purchase_count = 8  # 고객의 총 구매 횟수

# 할인율 설정
if purchase_count >= 10:
    discount = 20  # 20% 할인
elif 5 <= purchase_count < 10:
    discount = 10  # 10% 할인
else:
    discount = 5  # 5% 기본 할인

# 할인율 적용 메시지 출력
print(f"{customer_name}님, 이번 구매 시 {discount}% 할인이 적용됩니다!")
# Out:
# 김철수님, 이번 구매 시 10% 할인이 적용됩니다!

# %% [markdown]
# ### **7. 고객 리뷰 점수 분석 후 응답 자동화**

# %%
customer_review = "배송이 너무 늦고 제품도 마음에 안 들어요."
review_score = 2  # 고객이 남긴 별점 (1~5)

# 리뷰에 따른 응답 설정
if review_score >= 4:
    response = "고객님, 좋은 평가 감사합니다! 앞으로도 만족을 드리겠습니다. 😊"
elif 2 <= review_score < 4:
    response = "소중한 의견 감사드립니다. 더 나은 서비스를 위해 노력하겠습니다!"
else:
    response = "불편을 끼쳐드려 죄송합니다. 고객님의 의견을 바탕으로 개선하겠습니다. 🙏"

# 자동 응답 출력
print(response)
# Out:
# 소중한 의견 감사드립니다. 더 나은 서비스를 위해 노력하겠습니다!

# %% [markdown]
# ### **8. 광고 예산 설정 및 캠페인 전략 조정**

# %%
monthly_budget = 1200000  # 월간 광고 예산 (원)

# 광고 전략 추천
if monthly_budget >= 5000000:
    strategy = "프리미엄 캠페인 (SNS, 유튜브 광고 포함)"
elif 2000000 <= monthly_budget < 5000000:
    strategy = "중간 규모 캠페인 (구글 & 페이스북 광고 중심)"
elif 1000000 <= monthly_budget < 2000000:
    strategy = "소규모 캠페인 (네이버 블로그 & 인스타그램 활용)"
else:
    strategy = "저비용 바이럴 마케팅 (SNS 인플루언서 협업)"

# 전략 출력
print(f"현재 예산으로 추천되는 마케팅 전략: {strategy}")
# Out:
# 현재 예산으로 추천되는 마케팅 전략: 소규모 캠페인 (네이버 블로그 & 인스타그램 활용)

# %% [markdown]
# ### **9. 신규 고객 vs 기존 고객 혜택 차등 적용**

# %%
customer_email = "newuser@example.com"
is_new_customer = True  # True면 신규 고객, False면 기존 고객

# 혜택 설정
if is_new_customer:
    offer = "신규 고객 10% 할인 쿠폰 제공!"
else:
    offer = "기존 고객 감사 포인트 1,000점 적립!"

# 결과 출력
print(f"{customer_email}님, {offer}")
# Out:
# newuser@example.com님, 신규 고객 10% 할인 쿠폰 제공!

# %% [markdown]
# ### **10. 월 매출 목표 달성 여부 판단**

# %%
monthly_revenue = 12000000  # 이번 달 매출 (원)
target_revenue = 10000000  # 목표 매출 (원)

# 목표 달성 여부 확인
if monthly_revenue >= target_revenue:
    result = f"축하합니다! 목표 매출을 달성했습니다. (매출: {monthly_revenue:,.0f}원)"
else:
    result = f"목표에 도달하지 못했습니다. 추가 마케팅이 필요합니다. (매출: {monthly_revenue:,.0f}원)"

# 결과 출력
print(result)
# Out:
# 축하합니다! 목표 매출을 달성했습니다. (매출: 12,000,000원)
