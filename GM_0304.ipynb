# %% [markdown]
# #Day20. 머신러닝기초
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Tableau 기본 사용법과 데이터 연결**

# %% [markdown]
# ###**Tableau(테블루)**
# 데이터를 시각적으로 분석하고 대시보드를 생성하는 강력한 데이터 시각화 도구
# 사용자가 코드를 작성하지 않고도 데이터를 쉽게 분석하고 통찰력을 얻을 수 있도록 설계됨
# 직관적인 드래그 앤 드롭(Drag & Drop) 방식을 지원하여 데이터 분석 초보자부터 전문가까지 모두 활용 가능

# %% [markdown]
# ##**1. Tableau 주요 기능**

# %% [markdown]
# ### **① 데이터 연결**
#
# - 다양한 데이터 소스 연결 가능
#     - Excel, CSV, Google Sheets, JSON
#     - 관계형 데이터베이스(MySQL, PostgreSQL, MariaDB 등)
#     - 클라우드 데이터(Warehouse: Google BigQuery, AWS Redshift 등)
#
# ### **② 강력한 데이터 시각화**
#
# - 차트 및 그래프 생성: 막대 그래프, 선 그래프, 히트맵, 파이 차트, 지도 등
# - 대시보드 기능: 여러 시각화를 조합하여 **인터랙티브한 대시보드**를 생성
# - 실시간 데이터 분석: 데이터 변경 시 자동으로 반영
#
# ### **③ 간편한 데이터 분석**
#
# - 필터링 및 정렬: 데이터 필터링 및 그룹화 지원
# - 계산 필드 지원: SQL 없이도 간단한 계산 필드를 생성 가능
# - AI 및 머신러닝 기능 제공: 예측 분석 및 추세선 추가 가능
#
# ### **④ 협업 및 공유**
#
# - **Tableau Public (무료)**
#     - 온라인에 공유 가능 (공개 대시보드만 지원)
# - Tableau Server/Tableau Online (유료)
#     - 조직 내부에서 대시보드를 공유하고 협업 가능
# - PDF, 이미지, Excel로 내보내기 가능

# %% [markdown]
# ##**2. Tableau 제품 종류**

# %% [markdown]
# | 제품 | 설명 | 가격 |
# | --- | --- | --- |
# | **Tableau Public** | 무료 데이터 시각화 도구 (대시보드 공유 가능) | 무료 |
# | **Tableau Desktop** | 로컬 환경에서 강력한 데이터 시각화 지원 | 유료 |
# | **Tableau Server** | 기업 내부에서 대시보드 공유 및 협업 가능 | 유료 |
# | **Tableau Online** | 클라우드 기반의 협업용 대시보드 서비스 | 유료 |
# | **Tableau Prep** | 데이터 정제 및 변환을 위한 도구 | 유료 |

# %% [markdown]
# ##**3. Tableau 장점 & 단점**

# %% [markdown]
# ### **장점**
#
# - 직관적인 UI – 드래그 앤 드롭 방식으로 쉽게 사용 가능
# - 강력한 시각화 기능 – 고급 차트, 지도 기반 분석 가능
# - 다양한 데이터 연결 – Excel, 데이터베이스, 클라우드까지 연결 가능
# - 빠른 데이터 처리 – 대용량 데이터 분석 속도 우수
#
# ### **단점**
#
# - Tableau Public은 모든 데이터가 공개됨 (비공개 저장 불가)
# - 고급 기능은 유료 버전에서만 지원됨 (머신러닝, 예측 분석 등)
# - 무료 버전(Tableau Public)에서는 로컬 저장 불가능

# %% [markdown]
# ##**4. Tableau 사용 예시**

# %% [markdown]
# ### **매출 분석 대시보드 만들기**
#
# 1. Excel 또는 CSV 파일을 Tableau에 업로드
# 2. 날짜를 행(Row), 매출을 열(Column)로 드래그하여 **매출 그래프 생성**
# 3. 상품별 매출 비교 차트 생성
# 4. 대시보드에 추가하여 전체 매출 트렌드 확인
#
# ### **지역별 판매량 분석 (지도 시각화)**
#
# 1. 주소 또는 지역 데이터가 포함된 파일 업로드
# 2. Tableau에서 **지도 차트**를 선택하여 시각화
# 3. 지역별 매출을 색상으로 표현하여 분석

# %% [markdown]
# ## **5. Tableau 학습 자료**
#
# - **공식 사이트:** https://www.tableau.com/ko-kr
# - **무료 강의 (Tableau Public 사용법):** https://public.tableau.com/en-us/s/
# - **Tableau 학습 페이지:** https://www.tableau.com/learn/training

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**필터링**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**대시보드 만들기**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**대시보드 구성 연습 (그로스마케팅_성과지표.csv)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 가입자 수
#   - 최대: 108명
#   - 최소: 50명
# - 방문자 수
#   - 최대: 790명
#   - 최소: 500명

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 구매 전환율(%)
#   - 최대: 7.9
#   - 최소: 5.0
#   - 평균:
# - 광고 수익률(ROAS)
#   - 최대: 5.4
#   - 최소: 2.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**그로스마케팅_시각화_데이터.csv**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 방문자 수 가장 많았던 날짜: 2024-01-05 (4,926명)
# - 방문자 수 가장 적었던 날짜: 2024-01-09 (630명)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 가입자 수 가장 많았던 날짜: 2024-01-20 (493명)
# - 가입자 수 가장 적었던 날짜: 2024-01-11 (63명)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 구매 전환율 가장 높은 날짜: 2024-01-24 (9.88%)
# - 구매 전환율 가장 낮은 날짜: 2024-01-27 (1.05%)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 평균 주문 금액이 100,000원 이상인 날짜: 17개 일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 고객 유지율이 80% 이상인 날짜: 8개 일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 광고비용이 1,000,000원 이상 사용된 날짜: 28개 일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - ROAS 2.0 이하인 날짜: 8개 일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - ROAS 3.0 이상인 날짜: 18개 일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 총 매출이 가장 높은 날짜: 2024-01-08 (84,482,151원)
# - 총 매출이 가장 낮은 날짜: 2024-01-11 (2,553,705원)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 광고비용이 가장 많이 사용된 날짜: 2024-01-11 (9,892,712원)
# - 총 매출이 가장 높은 날짜와 다름

# %% [markdown]
# ---
#
# ##**서울시 상권분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 최고 매출: 홍대입구역 (588,228,254,591원)
# 최저 매출: 상수역 (61,829,216,473원)
#
# 홍대입구역
#   - 유동 인구가 가장 많음
#   - 인근에 병원 등 높은 매출 단가가 예상되는 상권이 밀집되어 있어 가장 높은 매출액을 기록했을 것으로 추정
#
# 연남동
#   - 연트럴파크 등 유명한 놀거리가 있고, 홍대 및 신촌과 인접하여 유동 인구가 높음
#
# 합정역
#   - 홍대와 인접하여 카페 및 레스토랑 등의 데이트 코스로 유명하나, 비교적 유동 인구가 적음
#
# 망원역
#   - 대부분이 주거상권으로 유동 인구가 적음

# %% [markdown]
# ![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)
