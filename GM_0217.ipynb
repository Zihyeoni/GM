# %% [markdown]
# #Day11. 데이터수집 및 전처리
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**API (Application Programming Interface)**

# %% [markdown]
# 애플리케이션 간의 데이터를 주고받고 기능을 호출할 수 있도록 하는 인터페이스
# 이를 통해 기업은 외부 서비스와 연동하여 데이터를 수집, 마케팅 자동화 구현, 맞춤형 고객 경험 제공 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ##**API Server 예시**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ###**Flask 웹페이지 추가**
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ##**API 역할과 중요성 in 그로스 마케팅**

# %% [markdown]
# API를 활용하면 다양한 마케팅 채널에서 데이터를 수집, 분석하여 신속한 의사 결정 내리기 가능
# - **데이터 통합 및 분석**: 여러 마케팅 채널에서 데이터 수집하여 분석
# - **개인화 마케팅**: 고객 행동 데이터 기반으로 맞춤형 이메일, 푸시 알림, 광고 캠페인 실행
# - **마케팅 자동화**: API 활용한 캠페인 자동화, 고객 세그먼트 분류 및 리타겟팅 전략 적용
# - **A/B 테스트 최적화**: API를 통해 다양한 버전의 콘텐츠를 동적으로 제공, 성과 분석

# %% [markdown]
# ##**그로스 마케팅에서 활용 가능한 API 유형**

# %% [markdown]
# (1) **광고 API**
#
# - **Google Ads API / Facebook Marketing API**
#     - 광고 캠페인을 자동 생성 및 관리
#     - 특정 타겟 그룹을 설정하여 효율적인 광고 집행
#     - 광고 성과 데이터를 실시간으로 분석하고 최적화
#
# (2) **분석 및 트래킹 API**
#
# - **Google Analytics API**
#     - 웹사이트 및 앱의 사용자 데이터를 실시간 수집
#     - 유입 경로, 페이지 이탈률, 전환율 등의 핵심 지표 분석
#     - 마케팅 성과에 따른 자동 보고서 생성
#
# (3) **CRM 및 고객 데이터 API**
#
# - **HubSpot API / Salesforce API**
#     - 고객의 구매 이력, 문의 기록을 실시간으로 분석하여 맞춤형 마케팅 진행
#     - 고객 세그먼트를 분류하여 개인화된 이메일 캠페인 자동화
#     - 고객 유입부터 구매까지의 여정을 추적하고 자동 리타겟팅 실행
#
# (4) **이메일 & 메시징 API**
#
# - **Twilio API / SendGrid API**
#     - 고객 행동에 따라 이메일, SMS, 푸시 알림을 자동 발송
#     - 결제 알림, 장바구니 이탈 방지 메시지, 프로모션 메시지 등 자동화
#     - API를 이용해 A/B 테스트 실행 및 최적의 마케팅 메시지 도출
#
# (5) **소셜 미디어 API**
#
# - **Twitter API / Instagram Graph API**
#     - 소셜 미디어 데이터를 분석하여 트렌드 파악 및 해시태그 최적화
#     - 브랜드 언급 모니터링을 통해 실시간 고객 피드백 수집
#     - 자동 포스팅 및 사용자 참여 데이터 분석

# %% [markdown]
# ##**API를 활용한 그로스 마케팅 전략**

# %% [markdown]
# **(1) 자동화된 고객 세그멘테이션**
#
# - Google Analytics API + CRM API를 결합하여 고객 데이터를 자동 분류
# - 구매 패턴, 방문 빈도, 관심 제품 등을 기준으로 고객을 세그먼트화
# - 세그먼트별 맞춤형 광고 및 이메일 캠페인 실행
#
# **(2) 마케팅 캠페인 자동화**
#
# - Facebook Ads API를 활용하여 특정 고객 그룹을 대상으로 광고 자동 집행
# - SendGrid API로 특정 행동을 한 고객에게 자동 이메일 전송 (예: 장바구니 이탈 고객 리마인드)
# - Twilio API를 사용해 결제 완료 후 고객에게 SMS로 프로모션 코드 발송
#
# **(3) 실시간 트래킹 및 성과 분석**
#
# - API 기반으로 실시간 대시보드를 구축하여 마케팅 성과를 추적
# - 광고 성과를 분석하고 자동으로 광고 예산 재조정
# - 소셜 미디어 API를 이용해 실시간 브랜드 언급 및 고객 반응 모니터링
#
# **(4) 리타겟팅 및 개인화 마케팅**
#
# - 고객의 웹사이트 방문 데이터를 API로 분석하여 맞춤형 광고 제공
# - HubSpot API와 결합하여 고객 맞춤형 이메일 마케팅 실행
# - AI 기반 추천 API(OpenAI API 등)를 활용하여 고객 맞춤형 제품 추천

# %% [markdown]
# ##**API 활용 시 고려해야 할 사항**

# %% [markdown]
# - **데이터 보안 및 개인정보 보호**: API 사용 시 GDPR, CCPA 등 데이터 보호 규정 준수해야 함
# - **API 요청 제한(Rate Limit)**: 특정 API는 요청 횟수 제한이 있으며, 효율적인 API 호출 전략 필요
# - **데이터 동기화 문제**: 여러 API에서 데이터를 가져올 경우 실시간 동기화를 고려해야 함
# - **API 업데이트 및 유지보수**: 사용 중인 API의 버전이 업데이트되거나 폐기될 수 있어 지속적인 관리 필요

# %% [markdown]
# ##**API를 활용한 그로스 마케팅의 기대 효과**

# %% [markdown]
# - **개발 시간 단축**: 기존 서비스와의 연동을 통해 빠른 구현 가능
# - **마케팅 자동화**: 수동 프로세스를 줄이고 효율적인 마케팅 캠페인 운영
# - **데이터 기반 의사 결정**: 실시간 데이터 분석으로 최적화된 마케팅 전략 수립
# - **고객 경험 향상**: 개인화된 마케팅을 통해 고객 만족도 증가

# %% [markdown]
# ---

# %% [markdown]
# ##**API 데이터 수집 심화**

# %% [markdown]
# ### Google Analytics에서 가져온 데이터
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# 하드코딩된 Google Analytics 사용자 행동 데이터 (30일)
data = {
    "Date": pd.date_range(start="2024-01-01", periods=30, freq="D"),
    "Sessions": [
        1000, 1200, 1100, 1300, 1150, 1400, 1250, 1500, 1350, 1600,
        1700, 1800, 1750, 1900, 1850, 1950, 2000, 2100, 2200, 2300,
        2250, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200
    ],
    "Users": [
        800, 950, 870, 1000, 920, 1100, 980, 1200, 1050, 1300,
        1400, 1450, 1350, 1500, 1400, 1550, 1600, 1700, 1750, 1850,
        1800, 1950, 2000, 2100, 2200, 2300, 2350, 2450, 2500, 2600
    ],
    "New_Users": [
        300, 400, 350, 450, 380, 500, 420, 550, 460, 600,
        620, 650, 640, 700, 680, 720, 750, 800, 850, 900,
        870, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350
    ],
    "Pageviews": [
        4000, 4500, 4200, 4800, 4300, 5000, 4600, 5200, 4800, 5500,
        6000, 6500, 6200, 7000, 6800, 7200, 7500, 7800, 8000, 8200,
        8500, 8700, 9000, 9500, 9800, 10000, 10500, 11000, 11500, 12000
    ],
    "Pages_per_Session": [
        4.0, 3.8, 3.9, 3.7, 3.8, 3.6, 3.7, 3.5, 3.6, 3.4,
        3.9, 4.0, 3.8, 4.1, 4.2, 4.0, 4.3, 4.5, 4.4, 4.6,
        4.2, 4.1, 4.3, 4.5, 4.6, 4.7, 4.8, 4.9, 5.0, 5.1
    ]
}

# 데이터프레임 생성
google_analytics_data = pd.DataFrame(data)

# CSV 파일로 저장
csv_filename = "google_analytics_data.csv"
google_analytics_data.to_csv(csv_filename, index=False)

print(f"CSV 파일 '{csv_filename}' 저장 완료!")
# Out:
# CSV 파일 'google_analytics_data.csv' 저장 완료!

# %%
import matplotlib.pyplot as plt

# CSV 파일 로드
csv_filename = "google_analytics_data.csv"
google_analytics_data = pd.read_csv(csv_filename)

# 주요 지표 계산
total_sessions = google_analytics_data["Sessions"].sum()
total_users = google_analytics_data["Users"].sum()
total_new_users = google_analytics_data["New_Users"].sum()
total_pageviews = google_analytics_data["Pageviews"].sum()
avg_pages_per_session = round(google_analytics_data["Pages_per_Session"].mean(), 2)

# 신규 사용자 비율 계산
new_user_ratio = round((total_new_users / total_users) * 100, 2)

# 데이터 시각화: 세션 수 및 페이지뷰 수
plt.figure(figsize=(10, 5))
plt.plot(google_analytics_data["Date"], google_analytics_data["Sessions"], label="Sessions", marker='o', linestyle='-')
plt.plot(google_analytics_data["Date"], google_analytics_data["Pageviews"], label="Pageviews", marker='s', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Count")
plt.title("Daily Sessions and Pageviews")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# 데이터 시각화: 신규 사용자 비율
plt.figure(figsize=(8, 5))
plt.bar(["New Users", "Returning Users"], [total_new_users, total_users - total_new_users], color=['blue', 'gray'])
plt.xlabel("User Type")
plt.ylabel("Count")
plt.title(f"New Users vs Returning Users (New User Ratio: {new_user_ratio}%)")
plt.grid(axis='y')
plt.show()

# 데이터 시각화: 세션당 페이지뷰 평균
plt.figure(figsize=(8, 5))
plt.bar(["Average Pages per Session"], [avg_pages_per_session], color='green')
plt.ylabel("Pages per Session")
plt.title("Average Pages per Session Over Time")
plt.ylim(0, max(google_analytics_data["Pages_per_Session"]) + 1)
plt.grid(axis='y')
plt.show()

# 주요 지표 출력
summary_metrics = {
    "Total Sessions": total_sessions,
    "Total Users": total_users,
    "Total New Users": total_new_users,
    "New User Ratio (%)": new_user_ratio,
    "Total Pageviews": total_pageviews,
    "Average Pages per Session": avg_pages_per_session,
}

# 데이터프레임 생성 및 출력
summary_df = pd.DataFrame(summary_metrics, index=[0])
print(summary_df)
# Out:
#    Total Sessions  Total Users  Total New Users  New User Ratio (%)  \
# 0           59850        47970            22940               47.82
#
#    Total Pageviews  Average Pages per Session
# 0           218600                       4.17

# %% [markdown]
# ---

# %% [markdown]
# ###**실력 강화 문제**

# %%
import pandas as pd

# 하드코딩된 Google Analytics 사용자 행동 데이터 (10일)
data = {
    "Date": pd.date_range(start="2024-01-01", periods=10, freq="D"),
    "Sessions": [
        150, 180, 200, 220, 250, 230, 210, 240, 260, 270
    ],
    "Users": [
        120, 140, 160, 170, 190, 180, 170, 185, 195, 200
    ],
    "New_Users": [
        80, 90, 100, 110, 120, 110, 100, 115, 130, 140
    ],
    "Pageviews": [
        500, 540, 600, 660, 750, 690, 630, 720, 780, 810
    ],
    "Pages_per_Session": [
        3.33, 3.00, 3.00, 3.00, 3.00, 3.00, 3.00, 3.00, 3.00, 3.00
    ]
}

# 데이터프레임 생성
google_analytics_data2 = pd.DataFrame(data)

# CSV 파일로 저장
csv_filename = "google_analytics_data2.csv"
google_analytics_data2.to_csv(csv_filename, index=False)

print(f"CSV 파일 '{csv_filename}' 저장 완료!")
# Out:
# CSV 파일 'google_analytics_data2.csv' 저장 완료!

# %%
import matplotlib.pyplot as plt

# CSV 파일 로드
csv_filename = "google_analytics_data2.csv"
google_analytics_data2 = pd.read_csv(csv_filename)

# 주요 지표 계산
total_sessions = google_analytics_data2["Sessions"].sum()
total_users = google_analytics_data2["Users"].sum()
total_new_users = google_analytics_data2["New_Users"].sum()
total_pageviews = google_analytics_data2["Pageviews"].sum()
avg_pages_per_session = round(google_analytics_data2["Pages_per_Session"].mean(), 2)

# 신규 사용자 비율 계산
new_user_ratio = round((total_new_users / total_users) * 100, 2)

# 데이터 시각화: 세션 수 및 페이지뷰 수
plt.figure(figsize=(10, 5))
plt.plot(google_analytics_data2["Date"], google_analytics_data2["Sessions"], label="Sessions", marker='o', linestyle='-')
plt.plot(google_analytics_data2["Date"], google_analytics_data2["Pageviews"], label="Pageviews", marker='s', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Count")
plt.title("Daily Sessions and Pageviews")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# 데이터 시각화: 신규 사용자 비율
plt.figure(figsize=(8, 5))
plt.bar(["New Users", "Returning Users"], [total_new_users, total_users - total_new_users], color=['blue', 'gray'])
plt.xlabel("User Type")
plt.ylabel("Count")
plt.title(f"New Users vs Returning Users (New User Ratio: {new_user_ratio}%)")
plt.grid(axis='y')
plt.show()

# 데이터 시각화: 세션당 페이지뷰 평균
plt.figure(figsize=(8, 5))
plt.bar(["Average Pages per Session"], [avg_pages_per_session], color='green')
plt.ylabel("Pages per Session")
plt.title("Average Pages per Session Over Time")
plt.ylim(0, max(google_analytics_data2["Pages_per_Session"]) + 1)
plt.grid(axis='y')
plt.show()

# 주요 지표 출력
summary_metrics = {
    "Total Sessions": total_sessions,
    "Total Users": total_users,
    "Total New Users": total_new_users,
    "New User Ratio (%)": new_user_ratio,
    "Total Pageviews": total_pageviews,
    "Average Pages per Session": avg_pages_per_session,
}

# 데이터프레임 생성 및 출력
summary_df = pd.DataFrame(summary_metrics, index=[0])
print(summary_df)
# Out:
#    Total Sessions  Total Users  Total New Users  New User Ratio (%)  \
# 0            2210         1710             1095               64.04
#
#    Total Pageviews  Average Pages per Session
# 0             6680                       3.03

# %% [markdown]
# ---

# %% [markdown]
# ##**트래픽 소스 및 전환(Conversion) 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# 하드코딩된 트래픽 소스 데이터 (30일)
data = {
    "Date": pd.date_range(start="2024-01-01", periods=30, freq="D"),
    "Traffic_Source": [
        "Organic Search", "Direct", "Referral", "Social", "Paid Search"] * 6,
    "Visitors": [
        3200, 2100, 1500, 1800, 1200,
        3300, 2200, 1600, 1900, 1300,
        3400, 2300, 1700, 2000, 1400,
        3500, 2400, 1800, 2100, 1500,
        3600, 2500, 1900, 2200, 1600,
        3700, 2600, 2000, 2300, 1700
    ],
    "Conversion_Rate": [
        3.8, 2.9, 1.5, 2.1, 4.5,
        3.9, 3.0, 1.6, 2.2, 4.6,
        4.0, 3.1, 1.7, 2.3, 4.7,
        4.1, 3.2, 1.8, 2.4, 4.8,
        4.2, 3.3, 1.9, 2.5, 4.9,
        4.3, 3.4, 2.0, 2.6, 5.0
    ]
}

# 데이터프레임 생성 및 CSV 저장
csv_filename = "traffic_source_data.csv"
traffic_data = pd.DataFrame(data)
traffic_data.to_csv(csv_filename, index=False)

print(f"CSV 파일 '{csv_filename}' 저장 완료!")
# Out:
# CSV 파일 'traffic_source_data.csv' 저장 완료!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 로드
csv_filename = "traffic_source_data.csv"
traffic_data = pd.read_csv(csv_filename)

# 주요 지표 계산
total_visitors = traffic_data["Visitors"].sum()
avg_conversion_rate = round(traffic_data["Conversion_Rate"].mean(), 2)

# 트래픽 소스별 방문자 수 집계
traffic_source_summary = traffic_data.groupby("Traffic_Source")["Visitors"].sum().reset_index()

# 데이터 시각화: 트래픽 소스별 방문자 수
plt.figure(figsize=(8, 5))
plt.bar(traffic_source_summary["Traffic_Source"], traffic_source_summary["Visitors"], color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Traffic Source")
plt.ylabel("Total Visitors")
plt.title("Total Visitors by Traffic Source")
plt.grid(axis='y')
plt.show()

# 트래픽 소스별 평균 전환율 집계
traffic_conversion_summary = traffic_data.groupby("Traffic_Source")["Conversion_Rate"].mean().reset_index()

plt.figure(figsize=(8, 5))
plt.bar(traffic_conversion_summary["Traffic_Source"], traffic_conversion_summary["Conversion_Rate"], color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Traffic Source")
plt.ylabel("Average Conversion Rate (%)")
plt.title("Average Conversion Rate by Traffic Source")
plt.grid(axis='y')
plt.show()

# 주요 지표 출력
summary_metrics = {
    "Total Visitors": total_visitors,
    "Average Conversion Rate (%)": avg_conversion_rate
}

# 데이터프레임 생성 및 출력
summary_df = pd.DataFrame(summary_metrics, index=[0])
print(summary_df)
# Out:
#    Total Visitors  Average Conversion Rate (%)
# 0           66300                         3.21

# %% [markdown]
# ---
#
# ###**실력 강화 문제**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# 하드코딩된 트래픽 소스 데이터 (10일)
data = {
    "Date": pd.date_range(start="2024-01-01", periods=10, freq="D"),
    "Traffic_Source": [
        "Google", "Facebook", "Naver", "Direct", "Twitter",
        "Instagram", "Google", "Facebook", "Naver", "Direct"],
    "Referral": [
        50, 40, 60, 55, 65,
        70, 75, 80, 85, 90
    ],
    "Organic_Search": [
        200, 180, 220, 210, 230,
        240, 250, 260, 270, 280
    ],
    "Direct": [
        100, 110, 120, 130, 140,
        150, 160, 170, 180, 190
    ],
    "Social": [
        80, 90, 100, 110, 120,
        1430, 140, 150, 160, 170
    ],
    "Paid_Search": [
        30, 40, 50, 60, 70,
        80, 90, 100, 110, 120
    ]
}

# 데이터프레임 생성 및 CSV 저장
csv_filename = "traffic_source_data2.csv"
traffic_data2 = pd.DataFrame(data)
traffic_data2.to_csv(csv_filename, index=False)

print(f"CSV 파일 '{csv_filename}' 저장 완료!")
# Out:
# CSV 파일 'traffic_source_data2.csv' 저장 완료!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 로드
csv_filename = "traffic_source_data2.csv"
traffic_data = pd.read_csv(csv_filename)

# 1. 각 트래픽 소스의 총 방문자 수 계산
total_visitors = {
    "Referral": traffic_data["Referral"].sum(),
    "Organic_Search": traffic_data["Organic_Search"].sum(),
    "Direct": traffic_data["Direct"].sum(),
    "Social": traffic_data["Social"].sum(),
    "Paid_Search": traffic_data["Paid_Search"].sum(),
}

# 2. 가장 많은 방문자를 유입한 트래픽 소스 찾기
max_traffic_source = max(total_visitors, key=total_visitors.get)

# 3. 유기적 검색 트래픽(Organic Search)의 평균 방문자 수 계산
avg_organic_search = traffic_data["Organic_Search"].mean()

# 4. 소셜 트래픽(Social)과 직접 트래픽(Direct)의 총 방문자 수 차이 계산
social_vs_direct_diff = abs(traffic_data["Social"].sum() - traffic_data["Direct"].sum())

# 5. 유료 검색 트래픽(Paid Search)이 가장 높은 날의 날짜 찾기
max_paid_search_date = traffic_data.loc[traffic_data["Paid_Search"].idxmax(), "Date"]

# 결과 출력
results = {
    "Total Visitors per Traffic Source": total_visitors,
    "Highest Traffic Source": max_traffic_source,
    "Average Organic Search Traffic": avg_organic_search,
    "Difference Between Social and Direct Traffic": social_vs_direct_diff,
    "Date with Highest Paid Search Traffic": max_paid_search_date,
}

print("결과:", results)

# 시각화 - 트래픽 소스별 총 방문자 수 막대 그래프
plt.figure(figsize=(10, 5))
plt.bar(total_visitors.keys(), total_visitors.values(), alpha=0.7)
plt.xlabel("Traffic Source")
plt.ylabel("Total Visitors")
plt.title("Total Visitors per Traffic Source")
plt.xticks(rotation=45)
plt.show()

# 시각화 - 각 날짜별 Paid Search 트래픽 변화
plt.figure(figsize=(10, 5))
plt.plot(traffic_data["Date"], traffic_data["Paid_Search"], marker="o", linestyle="-", color="r", label="Paid Search")
plt.xlabel("Date")
plt.ylabel("Paid Search Traffic")
plt.title("Paid Search Traffic Over Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 결과: {'Total Visitors per Traffic Source': {'Referral': 670, 'Organic_Search': 2340, 'Direct': 1450, 'Social': 2550, 'Paid_Search': 750}, 'Highest Traffic Source': 'Social', 'Average Organic Search Traffic': 234.0, 'Difference Between Social and Direct Traffic': 1100, 'Date with Highest Paid Search Traffic': '2024-01-10'}

# %% [markdown]
# ---

# %% [markdown]
# ##**사용자 행동 흐름 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# 하드코딩된 사용자 행동 흐름 데이터 (30일)
data = {
    "Date": pd.date_range(start="2024-01-01", periods=30, freq="D"),
    "Landing_Page": [
        "Homepage", "Product Page", "Blog", "Pricing", "Contact"] * 6,
    "Exit_Page": [
        "Product Page", "Homepage", "Pricing", "Blog", "Contact"] * 6,
    "Bounce_Rate": [
        45.2, 50.1, 55.3, 40.8, 48.5,
        46.0, 49.5, 54.2, 39.9, 47.8,
        44.8, 51.2, 53.1, 41.5, 49.0,
        45.9, 48.7, 52.0, 40.2, 48.2,
        44.5, 50.6, 51.5, 39.5, 47.5,
        46.2, 49.3, 50.8, 38.9, 46.8
    ],
    "Average_Session_Duration": [
        180, 240, 150, 300, 200,
        190, 250, 140, 310, 210,
        185, 245, 160, 290, 205,
        175, 255, 155, 320, 195,
        180, 260, 165, 295, 185,
        170, 270, 170, 280, 190
    ]
}

# 데이터프레임 생성 및 CSV 저장
csv_filename = "user_behavior_data.csv"
user_behavior_data = pd.DataFrame(data)
user_behavior_data.to_csv(csv_filename, index=False)

print(f"CSV 파일 '{csv_filename}' 저장 완료!")
# Out:
# CSV 파일 'user_behavior_data.csv' 저장 완료!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 로드
csv_filename = "user_behavior_data.csv"
user_behavior_data = pd.read_csv(csv_filename)

# 주요 지표 계산
avg_bounce_rate = round(user_behavior_data["Bounce_Rate"].mean(), 2)
avg_session_duration = round(user_behavior_data["Average_Session_Duration"].mean(), 2)

# 랜딩 페이지별 평균 이탈률 계산
landing_page_bounce_summary = user_behavior_data.groupby("Landing_Page")["Bounce_Rate"].mean().reset_index()

# 종료 페이지별 방문 횟수 계산
exit_page_summary = user_behavior_data.groupby("Exit_Page").size().reset_index(name="Exit_Count")

# 주요 지표 출력
summary_metrics = {
    "Average Bounce Rate (%)": avg_bounce_rate,
    "Average Session Duration (seconds)": avg_session_duration
}

summary_df = pd.DataFrame([summary_metrics])

# 데이터 시각화
# 랜딩 페이지별 평균 이탈률 시각화
plt.figure(figsize=(8, 5))
plt.bar(landing_page_bounce_summary["Landing_Page"], landing_page_bounce_summary["Bounce_Rate"],
        color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Landing Page")
plt.ylabel("Average Bounce Rate (%)")
plt.title("Average Bounce Rate by Landing Page")
plt.grid(axis='y')
plt.show()

# 종료 페이지별 방문 횟수 시각화
plt.figure(figsize=(8, 5))
plt.bar(exit_page_summary["Exit_Page"], exit_page_summary["Exit_Count"],
        color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Exit Page")
plt.ylabel("Exit Count")
plt.title("Exit Count by Page")
plt.grid(axis='y')
plt.show()

# 주요 분석 결과 출력
print("\n랜딩 페이지별 평균 이탈률:")
print(landing_page_bounce_summary)

print("\n종료 페이지별 방문 횟수:")
print(exit_page_summary)

print("\n평균 이탈률 및 평균 세션 지속 시간:")
print(summary_df)
# Out:
# 랜딩 페이지별 평균 이탈률:
#    Landing_Page  Bounce_Rate
# 0          Blog    52.816667
# 1       Contact    47.966667
# 2      Homepage    45.433333
# 3       Pricing    40.133333
# 4  Product Page    49.900000
#
# 종료 페이지별 방문 횟수:
#       Exit_Page  Exit_Count
# 0          Blog           6
# 1       Contact           6
# 2      Homepage           6
# 3       Pricing           6
# 4  Product Page           6
#
# 평균 이탈률 및 평균 세션 지속 시간:
#    Average Bounce Rate (%)  Average Session Duration (seconds)
# 0                    47.25                              217.33

# %% [markdown]
# ---

# %% [markdown]
# ##**장치 및 지역 분석**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# 1. 하드코딩된 장치 및 지역 데이터 생성 및 CSV 저장
data = {
    "Date": pd.date_range(start="2024-01-01", periods=30, freq="D"),
    "Device_Category": [
        "Desktop", "Mobile", "Tablet", "Mobile", "Desktop"] * 6,
    "Operating_System": [
        "Windows", "iOS", "Android", "iOS", "MacOS"] * 6,
    "Geolocation": [
        "USA", "South Korea", "Germany", "Japan", "Canada"] * 6,
    "Language": [
        "en-US", "ko-KR", "de-DE", "ja-JP", "fr-CA"] * 6,
}

# 데이터프레임 생성 및 CSV 저장
csv_filename = "device_geolocation_data.csv"
device_geolocation_data = pd.DataFrame(data)
device_geolocation_data.to_csv(csv_filename, index=False)

print(f"CSV 파일 '{csv_filename}' 저장 완료!")
# Out:
# CSV 파일 'device_geolocation_data.csv' 저장 완료!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 2. 저장된 파일 로드 및 데이터 분석
csv_filename = "device_geolocation_data.csv"
device_geolocation_data = pd.read_csv(csv_filename)

# 주요 지표 계산
device_summary = device_geolocation_data["Device_Category"].value_counts().reset_index()
device_summary.columns = ["Device_Category", "Count"]

os_summary = device_geolocation_data["Operating_System"].value_counts().reset_index()
os_summary.columns = ["Operating_System", "Count"]

geolocation_summary = device_geolocation_data["Geolocation"].value_counts().reset_index()
geolocation_summary.columns = ["Geolocation", "Count"]

language_summary = device_geolocation_data["Language"].value_counts().reset_index()
language_summary.columns = ["Language", "Count"]

# 데이터 시각화
# 기기 유형별 방문 횟수
plt.figure(figsize=(8, 5))
plt.bar(device_summary["Device_Category"], device_summary["Count"], color=['blue', 'green', 'red'])
plt.xlabel("Device Category")
plt.ylabel("Count")
plt.title("Visits by Device Category")
plt.grid(axis='y')
plt.show()

# 운영 체제별 방문 횟수
plt.figure(figsize=(8, 5))
plt.bar(os_summary["Operating_System"], os_summary["Count"], color=['purple', 'orange', 'cyan', 'red', 'blue'])
plt.xlabel("Operating System")
plt.ylabel("Count")
plt.title("Visits by Operating System")
plt.grid(axis='y')
plt.show()

# 지역별 방문 횟수
plt.figure(figsize=(8, 5))
plt.bar(geolocation_summary["Geolocation"], geolocation_summary["Count"], color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Geolocation")
plt.ylabel("Count")
plt.title("Visits by Geolocation")
plt.grid(axis='y')
plt.show()

# 언어별 방문 횟수
plt.figure(figsize=(8, 5))
plt.bar(language_summary["Language"], language_summary["Count"], color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Language")
plt.ylabel("Count")
plt.title("Visits by Language")
plt.grid(axis='y')
plt.show()

# 주요 분석 결과 출력
print("\n기기 유형별 방문 횟수:")
print(device_summary)

print("\n운영 체제별 방문 횟수:")
print(os_summary)

print("\n지역별 방문 횟수:")
print(geolocation_summary)

print("\n언어별 방문 횟수:")
print(language_summary)
# Out:
# 기기 유형별 방문 횟수:
#   Device_Category  Count
# 0         Desktop     12
# 1          Mobile     12
# 2          Tablet      6
#
# 운영 체제별 방문 횟수:
#   Operating_System  Count
# 0              iOS     12
# 1          Windows      6
# 2          Android      6
# 3            MacOS      6
#
# 지역별 방문 횟수:
#    Geolocation  Count
# 0          USA      6
# 1  South Korea      6
# 2      Germany      6
# 3        Japan      6
# 4       Canada      6
#
# 언어별 방문 횟수:
#   Language  Count
# 0    en-US      6
# 1    ko-KR      6
# 2    de-DE      6
# 3    ja-JP      6
# 4    fr-CA      6

# %% [markdown]
# ---
#
# ##**Meta (Facebook)에서 가져온 데이터의 주요 분석 항목과 내용**
# Meta 광고 및 페이지 인사이트 데이터는 마케팅 성과를 분석하고 최적화하는 데 중요한 역할을 함
# API를 통해 가져올 수 있는 주요 데이터 항목과 그 의미를 정리

# %% [markdown]
# ###**1. 광고 성과 분석**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 활용 예시:
# - CTR이 낮다면 광고 크리에이티브를 변경하여 성과를 개선할 필요 있음
# - CRV이 높다면 광고 대상 그룹을 조정하여 비용 최적화 가능

# %% [markdown]
# ###**2. 전환(Conversion) 분석**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 활용 예시:
#
# - 전환율이 낮다면 랜딩 페이지를 최적화하거나 광고 타겟팅을 조정할 필요가 있음
# - ROAS를 분석하여 광고 투자 대비 수익성 평가 가능

# %% [markdown]
# ###**3. 타겟팅 및 오디언스 분석**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 활용 예시:
#
# - 특정 연령대에서 광고 성과가 높다면 해당 연령층을 타겟으로 광고 집중 가능
# - 모바일 사용자가 많다면 모바일 최적화된 광고 크리에이티브를 제작할 필요가 있음

# %% [markdown]
# ###**4. 페이지 및 콘텐츠 성과 분석**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 활용 예시:
#
# - 특정 유형의 콘텐츠에서 참여도가 높다면 유사한 콘텐츠를 더 많이 제작 가능
# - 동영상 시청 시간이 낮다면 초반 3초 안에 더 강한 메시지를 전달해야 함

# %% [markdown]
# ###**5. 메시징 및 커뮤니케이션 분석**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 활용 예시:
#
# - 고객 응대 속도를 높이기 위해 챗봇 활용 가능
# - 부정적인 댓글 비율이 높다면 고객 불만 사항을 분석하고 해결할 필요가 있음
